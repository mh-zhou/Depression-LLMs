# %% [markdown]
# ### SFT_data_create

# %%
import json
import csv
from tqdm import *

# 新的提示词模板
INSTRUCTION_TEMPLATE = """Criteria for determining if a tweet is depressed:

    - **Non-depressed Tweets**: A tweet is labeled as non-depressed if it shows joy, discusses depression generally without reflecting personal mental state, expresses casual tiredness or sadness (e.g., due to a sports team's loss), or temporary hopelessness. It may also convey any emotion other than depression.

    - **Depressed Tweets**: Express persistent hopelessness or disinterest, with symptoms like guilt, concentration problems, social withdrawal, lack of motivation, changes in weight/appetite, fatigue, reckless behavior (e.g., substance abuse), sensitivity, worthlessness, reduced productivity, low self-esteem, and excessive worry. Severe cases may involve delusions, hallucinations, or suicidal thoughts/behaviors.

    Based on the above criteria, determine if the following tweet indicates depression with a single choice option: (0) Non-depressed Tweets, (1) Depressed Tweets

    Please directly output option result (0), or (1)."""

# 输入输出路径
input_csv = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_train_binary.csv"
output_json = "/data/zhengtianlong/Private/Depressed/LlamaFactory/data/Deptweet_train_binary.json"

outout = []

with open(input_csv, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头（假设有表头）
    for row in tqdm(reader, desc="Processing"):
        # 假设列顺序为：id, text, target, label
        if len(row) < 4:
            continue
        _, text, label, _ = row  # 忽略 id 和 target
        if text is None or text.strip() == "" or label is None:
            continue
        # 确保 label 是字符串 "0" 或 "1"
        label = str(int(float(label)))  # 处理可能的数值格式
        # 构建完整指令（将 text 嵌入模板）
        instruction = INSTRUCTION_TEMPLATE # .format(text=text)
        outout.append({
            "instruction": instruction,
            "input": text,  # 文本已嵌入 instruction，此处留空
            "output": label
        })

# 写入 JSON 文件
with open(output_json, "w", encoding='utf-8') as json_file:
    json.dump(outout, json_file, ensure_ascii=False, indent=2)
# Out:
# Processing: 36171it [00:00, 183443.49it/s]

# %%
import json
import csv
from tqdm import *

# 新的提示词模板
INSTRUCTION_TEMPLATE = """Criteria for determining if a tweet is depressed:

    - **Non-depressed Tweets**: A tweet is labeled as non-depressed if it shows joy, discusses depression generally without reflecting personal mental state, expresses casual tiredness or sadness (e.g., due to a sports team's loss), or temporary hopelessness. It may also convey any emotion other than depression.

    - **Depressed Tweets**: Express persistent hopelessness or disinterest, with symptoms like guilt, concentration problems, social withdrawal, lack of motivation, changes in weight/appetite, fatigue, reckless behavior (e.g., substance abuse), sensitivity, worthlessness, reduced productivity, low self-esteem, and excessive worry. Severe cases may involve delusions, hallucinations, or suicidal thoughts/behaviors.

    Based on the above criteria, determine if the following tweet indicates depression with a single choice option: (0) Non-depressed Tweets, (1) Depressed Tweets

    Please directly output option result (0), or (1)."""

# 输入输出路径
input_csv = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test_binary.csv"
output_json = "/data/zhengtianlong/Private/Depressed/LlamaFactory/data/Deptweet_test_binary.json"

outout = []

with open(input_csv, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头（假设有表头）
    for row in tqdm(reader, desc="Processing"):
        # 假设列顺序为：id, text, target, label
        if len(row) < 4:
            continue
        _, text, label, _ = row  # 忽略 id 和 target
        if text is None or text.strip() == "" or label is None:
            continue
        # 确保 label 是字符串 "0" 或 "1"
        label = str(int(float(label)))  # 处理可能的数值格式
        # 构建完整指令（将 text 嵌入模板）
        instruction = INSTRUCTION_TEMPLATE # .format(text=text)
        outout.append({
            "instruction": instruction,
            "input": text,  # 文本已嵌入 instruction，此处留空
            "output": label
        })

# 写入 JSON 文件
with open(output_json, "w", encoding='utf-8') as json_file:
    json.dump(outout, json_file, ensure_ascii=False, indent=2)
# Out:
# Processing: 1408it [00:00, 104577.22it/s]

# %%
import json
import csv
from tqdm import *

# 新的提示词模板
INSTRUCTION_TEMPLATE = """The meanings of tweets at each depression level are as follows：
    - **Non-depressed Tweets**: These tweets express joy, make general statements about depression without personal mental state reflection, or convey casual tiredness, sadness, or temporary hopelessness. They may also express any non-depressive emotion.

    - **Mildly depressed Tweets**: These convey persistent hopelessness or disinterest, with symptoms like guilt, concentration issues, loss of interest, social withdrawal, lack of motivation, weight/appetite changes, daytime sleepiness and fatigue, or reckless behavior (such as, alcohol and drug abuse).

    - **Moderately depressed Tweets**: Similar to mild depression but severe enough to disrupt home/work activities. Symptoms include sensitivity, worthlessness, reduced productivity, low self-esteem, and excessive worry.

    - **Severely depressed Tweets**: These are marked by delusions, insensibility, hallucinations, or suicidal thoughts/behaviors, posing significant life threats.

    Based on the above depression level classification, determine the depression level of the tweet with single-choice options: (0) Non-depressed, (1) Mildly depressed, (2) Moderately depressed, (3) Severely depressed.

    Please directly output the depression level option 0, 1, 2, or 3."""

# 输入输出路径
input_csv = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_train.csv"
output_json = "/data/zhengtianlong/Private/Depressed/LlamaFactory/data/Deptweet_train_4.json"

outout = []

with open(input_csv, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头（假设有表头）
    for row in tqdm(reader, desc="Processing"):
        # 假设列顺序为：id, text, target, label
        if len(row) < 4:
            continue
        _, text, label, _ = row  # 忽略 id 和 target
        if text is None or text.strip() == "" or label is None:
            continue
        # 确保 label 是字符串 "0" 或 "1"
        label = str(int(float(label)))  # 处理可能的数值格式
        # 构建完整指令（将 text 嵌入模板）
        instruction = INSTRUCTION_TEMPLATE # .format(text=text)
        outout.append({
            "instruction": instruction,
            "input": text,  # 文本已嵌入 instruction，此处留空
            "output": label
        })

# 写入 JSON 文件
with open(output_json, "w", encoding='utf-8') as json_file:
    json.dump(outout, json_file, ensure_ascii=False, indent=2)
# Out:
# Processing: 0it [00:00, ?it/s]
# Processing: 36171it [00:00, 192161.37it/s]

# %%
import json
import csv
from tqdm import *

# 新的提示词模板
INSTRUCTION_TEMPLATE = """The meanings of tweets at each depression level are as follows：
    - **Non-depressed Tweets**: These tweets express joy, make general statements about depression without personal mental state reflection, or convey casual tiredness, sadness, or temporary hopelessness. They may also express any non-depressive emotion.

    - **Mildly depressed Tweets**: These convey persistent hopelessness or disinterest, with symptoms like guilt, concentration issues, loss of interest, social withdrawal, lack of motivation, weight/appetite changes, daytime sleepiness and fatigue, or reckless behavior (such as, alcohol and drug abuse).

    - **Moderately depressed Tweets**: Similar to mild depression but severe enough to disrupt home/work activities. Symptoms include sensitivity, worthlessness, reduced productivity, low self-esteem, and excessive worry.

    - **Severely depressed Tweets**: These are marked by delusions, insensibility, hallucinations, or suicidal thoughts/behaviors, posing significant life threats.

    Based on the above depression level classification, determine the depression level of the tweet with single-choice options: (0) Non-depressed, (1) Mildly depressed, (2) Moderately depressed, (3) Severely depressed.

    Please directly output the depression level option 0, 1, 2, or 3."""

# 输入输出路径
input_csv = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
output_json = "/data/zhengtianlong/Private/Depressed/LlamaFactory/data/Deptweet_test_4.json"

outout = []

with open(input_csv, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头（假设有表头）
    for row in tqdm(reader, desc="Processing"):
        # 假设列顺序为：id, text, target, label
        if len(row) < 4:
            continue
        _, text, label, _ = row  # 忽略 id 和 target
        if text is None or text.strip() == "" or label is None:
            continue
        # 确保 label 是字符串 "0" 或 "1"
        label = str(int(float(label)))  # 处理可能的数值格式
        # 构建完整指令（将 text 嵌入模板）
        instruction = INSTRUCTION_TEMPLATE # .format(text=text)
        outout.append({
            "instruction": instruction,
            "input": text,  # 文本已嵌入 instruction，此处留空
            "output": label
        })

# 写入 JSON 文件
with open(output_json, "w", encoding='utf-8') as json_file:
    json.dump(outout, json_file, ensure_ascii=False, indent=2)
# Out:
# Processing: 1408it [00:00, 100748.59it/s]

# %%
import json
from tqdm import tqdm

# 新的提示词模板
INSTRUCTION_TEMPLATE = """You are an expert in mental health analysis. Your task is to analyze a social media post and identify which of the following depression-related emotions are expressed in it. Each emotion is represented by a Chinese character code (甲, 乙, 丙, 丁, 戊, 己, 庚, 辛) with corresponding descriptions: 

甲: Anger – an intensified emotional response that can be directed inward or outward, contributing to despair and self-criticism.  
乙: Cognitive dysfunction – impairment in normal cognitive functioning, causing forgetfulness, slow thinking, difficulty expressing thoughts.  
丙: Emptiness – a deep emotional void, numbness, lack of vitality, feeling disconnected and an empty future.  
丁: Hopelessness – a susceptibility factor in depressive symptoms, intrinsic to depression.  
戊: Loneliness – profound isolation even in the presence of others, predisposing to depression.  
己: Sadness – a natural emotion triggered by events or losses, a fundamental symptom of depression.  
庚: Suicide intent – conscious desire to end one's life, indicating a serious mental health concern, often overwhelming emotional pain.  
辛: Worthlessness – a profound sense of having little or no value, feeling inadequate or undeserving.

Instructions:
1. Read the given post text carefully.
2. Based on the content, identify all emotions from the list above that are present or implied in the post. Each post is guaranteed to contain at least one of these emotions.
3. Return your answer as a comma-separated list of the corresponding Chinese codes (e.g., "丙, 丁" for emptiness and hopelessness). Do not include any additional text or explanation.
4. Only output the list.

Emotions expressed:"""

# 输入输出路径
input_json = "/data/zhengtianlong/Private/Depressed/DepressionEmo-main/Dataset/train.json"
output_json = "/data/zhengtianlong/Private/Depressed/LlamaFactory/data/DepressionEmo_train_8.json"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))
name_to_code = {v: k for k, v in code_to_name.items()}

output_data = []

# 读取 JSONL 文件（每行一个 JSON 对象）
with open(input_json, 'r', encoding='utf-8') as f:
    for line in tqdm(f, desc="Processing"):
        line = line.strip()
        if not line:
            continue

        try:
            item = json.loads(line)
        except json.JSONDecodeError:
            continue

        text = item.get("text")
        emotions = item.get("emotions", [])

        if not text or not str(text).strip() or not emotions:
            continue

        # 基于 emotions 构造 output，按固定顺序输出代码
        emotion_set = set(emotions)
        output_codes = [code for code, name in zip(emotion_codes, emotion_names) if name in emotion_set]

        if not output_codes:
            continue

        output_data.append({
            "instruction": INSTRUCTION_TEMPLATE,
            "input": text,   # 保持 text 不变
            "output": ", ".join(output_codes)
        })

# 写入 JSON 文件
with open(output_json, "w", encoding='utf-8') as json_file:
    json.dump(output_data, json_file, ensure_ascii=False, indent=2)

print(f"Saved {len(output_data)} samples to {output_json}")
# Out:
# Processing: 0it [00:00, ?it/s]
# Processing: 4225it [00:00, 45352.36it/s]
# Saved 4225 samples to /data/zhengtianlong/Private/Depressed/LlamaFactory/data/DepressionEmo_train_8.json

# %%
import json
from tqdm import tqdm

# 新的提示词模板
INSTRUCTION_TEMPLATE = """You are an expert in mental health analysis. Your task is to analyze a social media post and identify which of the following depression-related emotions are expressed in it. Each emotion is represented by a Chinese character code (甲, 乙, 丙, 丁, 戊, 己, 庚, 辛) with corresponding descriptions: 

甲: Anger – an intensified emotional response that can be directed inward or outward, contributing to despair and self-criticism.  
乙: Cognitive dysfunction – impairment in normal cognitive functioning, causing forgetfulness, slow thinking, difficulty expressing thoughts.  
丙: Emptiness – a deep emotional void, numbness, lack of vitality, feeling disconnected and an empty future.  
丁: Hopelessness – a susceptibility factor in depressive symptoms, intrinsic to depression.  
戊: Loneliness – profound isolation even in the presence of others, predisposing to depression.  
己: Sadness – a natural emotion triggered by events or losses, a fundamental symptom of depression.  
庚: Suicide intent – conscious desire to end one's life, indicating a serious mental health concern, often overwhelming emotional pain.  
辛: Worthlessness – a profound sense of having little or no value, feeling inadequate or undeserving.

Instructions:
1. Read the given post text carefully.
2. Based on the content, identify all emotions from the list above that are present or implied in the post. Each post is guaranteed to contain at least one of these emotions.
3. Return your answer as a comma-separated list of the corresponding Chinese codes (e.g., "丙, 丁" for emptiness and hopelessness). Do not include any additional text or explanation.
4. Only output the list.

Emotions expressed:"""

# 输入输出路径
input_json = "/data/zhengtianlong/Private/Depressed/DepressionEmo-main/Dataset/test.json"
output_json = "/data/zhengtianlong/Private/Depressed/LlamaFactory/data/DepressionEmo_test_8.json"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))
name_to_code = {v: k for k, v in code_to_name.items()}

output_data = []

# 读取 JSONL 文件（每行一个 JSON 对象）
with open(input_json, 'r', encoding='utf-8') as f:
    for line in tqdm(f, desc="Processing"):
        line = line.strip()
        if not line:
            continue

        try:
            item = json.loads(line)
        except json.JSONDecodeError:
            continue

        text = item.get("text")
        emotions = item.get("emotions", [])

        if not text or not str(text).strip() or not emotions:
            continue

        # 基于 emotions 构造 output，按固定顺序输出代码
        emotion_set = set(emotions)
        output_codes = [code for code, name in zip(emotion_codes, emotion_names) if name in emotion_set]

        if not output_codes:
            continue

        output_data.append({
            "instruction": INSTRUCTION_TEMPLATE,
            "input": text,   # 保持 text 不变
            "output": ", ".join(output_codes)
        })

# 写入 JSON 文件
with open(output_json, "w", encoding='utf-8') as json_file:
    json.dump(output_data, json_file, ensure_ascii=False, indent=2)

print(f"Saved {len(output_data)} samples to {output_json}")
# Out:
# Processing: 906it [00:00, 54577.88it/s]
# Saved 906 samples to /data/zhengtianlong/Private/Depressed/LlamaFactory/data/DepressionEmo_test_8.json

# %% [markdown]
# ## Deptweet_binary

# %% [markdown]
# ### Qwen3.5-0.8B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test_binary.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-0.8B-Base/lora/eval_2026-03-07-06-02-36/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：如果包含 '0' 返回0，否则如果包含 '1' 返回1，否则默认返回1"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    else:
        return 1  # 默认返回1

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        # target 可能为字符串 '0' 或 '1'，转为整数
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算指标
accuracy = accuracy_score(true_labels, pred_labels)
precision = precision_score(true_labels, pred_labels, pos_label=1) # pos_label=1 指定正类为抑郁（1）
recall = recall_score(true_labels, pred_labels, pos_label=1)
f1 = f1_score(true_labels, pred_labels, pos_label=1)

# 5. 打印结果
print("评估结果：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}")
print(f"精确率 (Precision): {precision*100:.2f}")
print(f"召回率 (Recall): {recall*100:.2f}")
print(f"F1 值 (F1-score): {f1*100:.2f}")
# Out:
# 评估结果：
# 准确率 (Accuracy): 87.14
# 精确率 (Precision): 90.35
# 召回率 (Recall): 58.39
# F1 值 (F1-score): 63.87

# %% [markdown]
# ### Qwen3.5-2B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test_binary.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-2B-Base/lora/eval_2026-03-07-08-38-34/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：如果包含 '0' 返回0，否则如果包含 '1' 返回1，否则默认返回1"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    else:
        return 1  # 默认返回1

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        # target 可能为字符串 '0' 或 '1'，转为整数
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算指标
accuracy = accuracy_score(true_labels, pred_labels)
precision = precision_score(true_labels, pred_labels, pos_label=1)
recall = recall_score(true_labels, pred_labels, pos_label=1)
f1 = f1_score(true_labels, pred_labels, pos_label=1)

# 5. 打印结果
print("评估结果：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}")
print(f"精确率 (Precision): {precision*100:.2f}")
print(f"召回率 (Recall): {recall*100:.2f}")
print(f"F1 值 (F1-score): {f1*100:.2f}")
# Out:
# 评估结果：
# 准确率 (Accuracy): 88.14
# 精确率 (Precision): 72.77
# 召回率 (Recall): 62.41
# F1 值 (F1-score): 67.19

# %% [markdown]
# ### Qwen3.5-4B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test_binary.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-4B-Base/lora/eval_2026-03-07-13-06-42/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：如果包含 '0' 返回0，否则如果包含 '1' 返回1，否则默认返回1"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    else:
        return 1  # 默认返回1

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        # target 可能为字符串 '0' 或 '1'，转为整数
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算指标
accuracy = accuracy_score(true_labels, pred_labels)
precision = precision_score(true_labels, pred_labels, pos_label=1)
recall = recall_score(true_labels, pred_labels, pos_label=1)
f1 = f1_score(true_labels, pred_labels, pos_label=1)

# 5. 打印结果
print("评估结果：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}")
print(f"精确率 (Precision): {precision*100:.2f}")
print(f"召回率 (Recall): {recall*100:.2f}")
print(f"F1 值 (F1-score): {f1*100:.2f}")
# Out:
# 评估结果：
# 准确率 (Accuracy): 87.86
# 精确率 (Precision): 72.29
# 召回率 (Recall): 60.95
# F1 值 (F1-score): 66.14

# %% [markdown]
# ### Qwen3.5-9B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test_binary.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-9B-Base/lora/eval_2026-03-08-00-54-52/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：如果包含 '0' 返回0，否则如果包含 '1' 返回1，否则默认返回1"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    else:
        return 1  # 默认返回1

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        # target 可能为字符串 '0' 或 '1'，转为整数
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算指标
accuracy = accuracy_score(true_labels, pred_labels)
precision = precision_score(true_labels, pred_labels, pos_label=1)
recall = recall_score(true_labels, pred_labels, pos_label=1)
f1 = f1_score(true_labels, pred_labels, pos_label=1)

# 5. 打印结果
print("评估结果：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}")
print(f"精确率 (Precision): {precision*100:.2f}")
print(f"召回率 (Recall): {recall*100:.2f}")
print(f"F1 值 (F1-score): {f1*100:.2f}")
# Out:
# 评估结果：
# 准确率 (Accuracy): 88.49
# 精确率 (Precision): 73.33
# 召回率 (Recall): 64.23
# F1 值 (F1-score): 68.48

# %% [markdown]
# ### Qwen3.5-35B-A3B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test_binary.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-35B-A3B-Base/lora/eval_2026-03-08-00-54-52/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：如果包含 '0' 返回0，否则如果包含 '1' 返回1，否则默认返回1"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    else:
        return 1  # 默认返回1

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        # target 可能为字符串 '0' 或 '1'，转为整数
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算指标
accuracy = accuracy_score(true_labels, pred_labels)
precision = precision_score(true_labels, pred_labels, pos_label=1)
recall = recall_score(true_labels, pred_labels, pos_label=1)
f1 = f1_score(true_labels, pred_labels, pos_label=1)

# 5. 打印结果
print("评估结果：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}")
print(f"精确率 (Precision): {precision*100:.2f}")
print(f"召回率 (Recall): {recall*100:.2f}")
print(f"F1 值 (F1-score): {f1*100:.2f}")
# Out:
# 评估结果：
# 准确率 (Accuracy): 89.28
# 精确率 (Precision): 75.73
# 召回率 (Recall): 66.06
# F1 值 (F1-score): 70.57

# %% [markdown]
# ## Deptweet_4

# %% [markdown]
# ### Qwen3.5-0.8B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-0.8B-Base/lora/eval_2026-03-08-05-39-59/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：按顺序查找 '0','1','2','3'，返回第一个匹配的数字，若均未找到则默认返回3"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认返回3（可调整）

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算四分类指标（使用宏平均 macro）
accuracy = accuracy_score(true_labels, pred_labels)
precision_macro = precision_score(true_labels, pred_labels, average='macro')
recall_macro = recall_score(true_labels, pred_labels, average='macro')
f1_macro = f1_score(true_labels, pred_labels, average='macro')

# 可选：加权平均
precision_weighted = precision_score(true_labels, pred_labels, average='weighted')
recall_weighted = recall_score(true_labels, pred_labels, average='weighted')
f1_weighted = f1_score(true_labels, pred_labels, average='weighted')

# 5. 打印主要结果（宏平均）
print("评估结果（宏平均 Macro）：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}%")
print(f"精确率 (Precision): {precision_macro*100:.2f}%")
print(f"召回率 (Recall): {recall_macro*100:.2f}%")
print(f"F1 值 (F1-score): {f1_macro*100:.2f}%")

# 可选：打印加权平均
print("\n评估结果（加权平均 Weighted）：")
print(f"精确率 (Precision): {precision_weighted*100:.2f}%")
print(f"召回率 (Recall): {recall_weighted*100:.2f}%")
print(f"F1 值 (F1-score): {f1_weighted*100:.2f}%")

# 可选：打印每个类别的详细指标
print("\n各类别详细指标：")
print(classification_report(true_labels, pred_labels, digits=4))
# Out:
# 评估结果（宏平均 Macro）：
# 准确率 (Accuracy): 83.31%
# 精确率 (Precision): 60.32%
# 召回率 (Recall): 50.97%
# F1 值 (F1-score): 54.53%
#
# 评估结果（加权平均 Weighted）：
# 精确率 (Precision): 81.09%
# 召回率 (Recall): 83.31%
# F1 值 (F1-score): 81.92%
#
# 各类别详细指标：
#               precision    recall  f1-score   support
#
#            0     0.8946    0.9506    0.9218      1134
#            1     0.4564    0.3696    0.4084       184
#            2     0.4118    0.2188    0.2857        64
#            3     0.6500    0.5000    0.5652        26
#
#     accuracy                         0.8331      1408
#    macro avg     0.6032    0.5097    0.5453      1408
# weighted avg     0.8109    0.8331    0.8192      1408

# %%
import json, csv
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# ================== 配置区域 ==================
# 字体路径（请确保文件存在）
font_path = '/data/zhengtianlong/ttf/timesi.ttf'
# 测试集CSV文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
# 预测结果JSONL文件路径
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-0.8B-Base/lora/eval_2026-03-08-05-39-59/generated_predictions.jsonl"
# 输出图片保存路径
output_img_path = "/data/zhengtianlong/Private/Depressed/result_IMG/Qwen3.5-0.8B-Base_ROC_curves.png"
# =============================================

# 加载字体
times_new_roman_font = fm.FontProperties(fname=font_path)

def map_label(predict_str):
    """
    从预测字符串中提取类别标签（0-3）。
    假设模型输出中可能包含数字 '0','1','2','3'，按顺序匹配第一个数字。
    若未匹配到任何数字，默认返回3（可根据实际情况调整）。
    """
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认类别

# 1. 读取测试集真实标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target（0/1/2/3）
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性并截断
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 构建与画图代码兼容的数据格式（列表 of dict）
data = [{"label": t, "predict": p} for t, p in zip(true_labels, pred_labels)]

# 5. 准备ROC曲线所需数据
y_true = [int(item["label"]) for item in data]
y_pred = [int(item["predict"]) for item in data]  # 此处predict已是整数

# 将标签二值化
n_classes = 4
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])

# 类别名称映射（可根据实际修改）
class_names = {0: "non-depressed", 1: "mild", 2: "moderate", 3: "severe"}

# 计算ROC曲线和AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_pred_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类别的ROC曲线
plt.figure()
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             lw=2, label=f'{class_names[i]} (area = {roc_auc[i]:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontproperties=times_new_roman_font)
plt.ylabel('True Positive Rate', fontproperties=times_new_roman_font)
plt.title('Receiver Operating Characteristic (ROC) for each level', fontproperties=times_new_roman_font)
plt.legend(loc="lower right", prop=times_new_roman_font)

# 设置刻度字体
plt.xticks(fontproperties=times_new_roman_font)
plt.yticks(fontproperties=times_new_roman_font)

plt.savefig(output_img_path, format='png', dpi=800, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Qwen3.5-2B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-2B-Base/lora/eval_2026-03-08-08-22-14/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：按顺序查找 '0','1','2','3'，返回第一个匹配的数字，若均未找到则默认返回3"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认返回3（可调整）

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算四分类指标（使用宏平均 macro）
accuracy = accuracy_score(true_labels, pred_labels)
precision_macro = precision_score(true_labels, pred_labels, average='macro')
recall_macro = recall_score(true_labels, pred_labels, average='macro')
f1_macro = f1_score(true_labels, pred_labels, average='macro')

# 可选：加权平均
precision_weighted = precision_score(true_labels, pred_labels, average='weighted')
recall_weighted = recall_score(true_labels, pred_labels, average='weighted')
f1_weighted = f1_score(true_labels, pred_labels, average='weighted')

# 5. 打印主要结果（宏平均）
print("评估结果（宏平均 Macro）：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}%")
print(f"精确率 (Precision): {precision_macro*100:.2f}%")
print(f"召回率 (Recall): {recall_macro*100:.2f}%")
print(f"F1 值 (F1-score): {f1_macro*100:.2f}%")

# 可选：打印加权平均
print("\n评估结果（加权平均 Weighted）：")
print(f"精确率 (Precision): {precision_weighted*100:.2f}%")
print(f"召回率 (Recall): {recall_weighted*100:.2f}%")
print(f"F1 值 (F1-score): {f1_weighted*100:.2f}%")

# 可选：打印每个类别的详细指标
print("\n各类别详细指标：")
print(classification_report(true_labels, pred_labels, digits=4))
# Out:
# 评估结果（宏平均 Macro）：
# 准确率 (Accuracy): 83.45%
# 精确率 (Precision): 55.60%
# 召回率 (Recall): 51.45%
# F1 值 (F1-score): 52.87%
#
# 评估结果（加权平均 Weighted）：
# 精确率 (Precision): 81.27%
# 召回率 (Recall): 83.45%
# F1 值 (F1-score): 82.15%
#
# 各类别详细指标：
#               precision    recall  f1-score   support
#
#            0     0.9022    0.9515    0.9262      1134
#            1     0.4698    0.3804    0.4204       184
#            2     0.3333    0.1875    0.2400        64
#            3     0.5185    0.5385    0.5283        26
#
#     accuracy                         0.8345      1408
#    macro avg     0.5560    0.5145    0.5287      1408
# weighted avg     0.8127    0.8345    0.8215      1408

# %%
import json, csv
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# ================== 配置区域 ==================
# 字体路径（请确保文件存在）
font_path = '/data/zhengtianlong/ttf/timesi.ttf'
# 测试集CSV文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
# 预测结果JSONL文件路径
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-2B-Base/lora/eval_2026-03-08-08-22-14/generated_predictions.jsonl"
# 输出图片保存路径
output_img_path = "/data/zhengtianlong/Private/Depressed/result_IMG/Qwen3.5-2B-Base_ROC_curves.png"
# =============================================

# 加载字体
times_new_roman_font = fm.FontProperties(fname=font_path)

def map_label(predict_str):
    """
    从预测字符串中提取类别标签（0-3）。
    假设模型输出中可能包含数字 '0','1','2','3'，按顺序匹配第一个数字。
    若未匹配到任何数字，默认返回3（可根据实际情况调整）。
    """
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认类别

# 1. 读取测试集真实标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target（0/1/2/3）
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性并截断
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 构建与画图代码兼容的数据格式（列表 of dict）
data = [{"label": t, "predict": p} for t, p in zip(true_labels, pred_labels)]

# 5. 准备ROC曲线所需数据
y_true = [int(item["label"]) for item in data]
y_pred = [int(item["predict"]) for item in data]  # 此处predict已是整数

# 将标签二值化
n_classes = 4
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])

# 类别名称映射（可根据实际修改）
class_names = {0: "non-depressed", 1: "mild", 2: "moderate", 3: "severe"}

# 计算ROC曲线和AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_pred_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类别的ROC曲线
plt.figure()
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             lw=2, label=f'{class_names[i]} (area = {roc_auc[i]:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontproperties=times_new_roman_font)
plt.ylabel('True Positive Rate', fontproperties=times_new_roman_font)
plt.title('Receiver Operating Characteristic (ROC) for each level', fontproperties=times_new_roman_font)
plt.legend(loc="lower right", prop=times_new_roman_font)

# 设置刻度字体
plt.xticks(fontproperties=times_new_roman_font)
plt.yticks(fontproperties=times_new_roman_font)

plt.savefig(output_img_path, format='png', dpi=800, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Qwen3.5-4B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-4B-Base/lora/eval_2026-03-08-10-57-36/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：按顺序查找 '0','1','2','3'，返回第一个匹配的数字，若均未找到则默认返回3"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认返回3（可调整）

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算四分类指标（使用宏平均 macro）
accuracy = accuracy_score(true_labels, pred_labels)
precision_macro = precision_score(true_labels, pred_labels, average='macro')
recall_macro = recall_score(true_labels, pred_labels, average='macro')
f1_macro = f1_score(true_labels, pred_labels, average='macro')

# 可选：加权平均
precision_weighted = precision_score(true_labels, pred_labels, average='weighted')
recall_weighted = recall_score(true_labels, pred_labels, average='weighted')
f1_weighted = f1_score(true_labels, pred_labels, average='weighted')

# 5. 打印主要结果（宏平均）
print("评估结果（宏平均 Macro）：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}%")
print(f"精确率 (Precision): {precision_macro*100:.2f}%")
print(f"召回率 (Recall): {recall_macro*100:.2f}%")
print(f"F1 值 (F1-score): {f1_macro*100:.2f}%")

# 可选：打印加权平均
print("\n评估结果（加权平均 Weighted）：")
print(f"精确率 (Precision): {precision_weighted*100:.2f}%")
print(f"召回率 (Recall): {recall_weighted*100:.2f}%")
print(f"F1 值 (F1-score): {f1_weighted*100:.2f}%")

# 可选：打印每个类别的详细指标
print("\n各类别详细指标：")
print(classification_report(true_labels, pred_labels, digits=4))
# Out:
# 评估结果（宏平均 Macro）：
# 准确率 (Accuracy): 84.09%
# 精确率 (Precision): 62.13%
# 召回率 (Recall): 57.73%
# F1 值 (F1-score): 59.49%
#
# 评估结果（加权平均 Weighted）：
# 精确率 (Precision): 82.36%
# 召回率 (Recall): 84.09%
# F1 值 (F1-score): 83.08%
#
# 各类别详细指标：
#               precision    recall  f1-score   support
#
#            0     0.9073    0.9497    0.9280      1134
#            1     0.4671    0.3859    0.4226       184
#            2     0.4186    0.2812    0.3364        64
#            3     0.6923    0.6923    0.6923        26
#
#     accuracy                         0.8409      1408
#    macro avg     0.6213    0.5773    0.5949      1408
# weighted avg     0.8236    0.8409    0.8308      1408

# %%
import json, csv
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# ================== 配置区域 ==================
# 字体路径（请确保文件存在）
font_path = '/data/zhengtianlong/ttf/timesi.ttf'
# 测试集CSV文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
# 预测结果JSONL文件路径
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-4B-Base/lora/eval_2026-03-08-10-57-36/generated_predictions.jsonl"
# 输出图片保存路径
output_img_path = "/data/zhengtianlong/Private/Depressed/result_IMG/Qwen3.5-4B-Base_ROC_curves.png"
# =============================================

# 加载字体
times_new_roman_font = fm.FontProperties(fname=font_path)

def map_label(predict_str):
    """
    从预测字符串中提取类别标签（0-3）。
    假设模型输出中可能包含数字 '0','1','2','3'，按顺序匹配第一个数字。
    若未匹配到任何数字，默认返回3（可根据实际情况调整）。
    """
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认类别

# 1. 读取测试集真实标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target（0/1/2/3）
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性并截断
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 构建与画图代码兼容的数据格式（列表 of dict）
data = [{"label": t, "predict": p} for t, p in zip(true_labels, pred_labels)]

# 5. 准备ROC曲线所需数据
y_true = [int(item["label"]) for item in data]
y_pred = [int(item["predict"]) for item in data]  # 此处predict已是整数

# 将标签二值化
n_classes = 4
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])

# 类别名称映射（可根据实际修改）
class_names = {0: "non-depressed", 1: "mild", 2: "moderate", 3: "severe"}

# 计算ROC曲线和AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_pred_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类别的ROC曲线
plt.figure()
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             lw=2, label=f'{class_names[i]} (area = {roc_auc[i]:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontproperties=times_new_roman_font)
plt.ylabel('True Positive Rate', fontproperties=times_new_roman_font)
plt.title('Receiver Operating Characteristic (ROC) for each level', fontproperties=times_new_roman_font)
plt.legend(loc="lower right", prop=times_new_roman_font)

# 设置刻度字体
plt.xticks(fontproperties=times_new_roman_font)
plt.yticks(fontproperties=times_new_roman_font)

plt.savefig(output_img_path, format='png', dpi=800, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Qwen3.5-9B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-9B-Base/lora/eval_2026-03-08-20-34-30/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：按顺序查找 '0','1','2','3'，返回第一个匹配的数字，若均未找到则默认返回3"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认返回3（可调整）

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算四分类指标（使用宏平均 macro）
accuracy = accuracy_score(true_labels, pred_labels)
precision_macro = precision_score(true_labels, pred_labels, average='macro')
recall_macro = recall_score(true_labels, pred_labels, average='macro')
f1_macro = f1_score(true_labels, pred_labels, average='macro')

# 可选：加权平均
precision_weighted = precision_score(true_labels, pred_labels, average='weighted')
recall_weighted = recall_score(true_labels, pred_labels, average='weighted')
f1_weighted = f1_score(true_labels, pred_labels, average='weighted')

# 5. 打印主要结果（宏平均）
print("评估结果（宏平均 Macro）：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}%")
print(f"精确率 (Precision): {precision_macro*100:.2f}%")
print(f"召回率 (Recall): {recall_macro*100:.2f}%")
print(f"F1 值 (F1-score): {f1_macro*100:.2f}%")

# 可选：打印加权平均
print("\n评估结果（加权平均 Weighted）：")
print(f"精确率 (Precision): {precision_weighted*100:.2f}%")
print(f"召回率 (Recall): {recall_weighted*100:.2f}%")
print(f"F1 值 (F1-score): {f1_weighted*100:.2f}%")

# 可选：打印每个类别的详细指标
print("\n各类别详细指标：")
print(classification_report(true_labels, pred_labels, digits=4))
# Out:
# 评估结果（宏平均 Macro）：
# 准确率 (Accuracy): 84.38%
# 精确率 (Precision): 62.69%
# 召回率 (Recall): 58.53%
# F1 值 (F1-score): 60.22%
#
# 评估结果（加权平均 Weighted）：
# 精确率 (Precision): 82.85%
# 召回率 (Recall): 84.38%
# F1 值 (F1-score): 83.49%
#
# 各类别详细指标：
#               precision    recall  f1-score   support
#
#            0     0.9119    0.9497    0.9305      1134
#            1     0.4713    0.4022    0.4340       184
#            2     0.4318    0.2969    0.3519        64
#            3     0.6923    0.6923    0.6923        26
#
#     accuracy                         0.8438      1408
#    macro avg     0.6269    0.5853    0.6022      1408
# weighted avg     0.8285    0.8438    0.8349      1408

# %%
import json, csv
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# ================== 配置区域 ==================
# 字体路径（请确保文件存在）
font_path = '/data/zhengtianlong/ttf/timesi.ttf'
# 测试集CSV文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
# 预测结果JSONL文件路径
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-9B-Base/lora/eval_2026-03-08-20-34-30/generated_predictions.jsonl"
# 输出图片保存路径
output_img_path = "/data/zhengtianlong/Private/Depressed/result_IMG/Qwen3.5-9B-Base_ROC_curves.png"
# =============================================

# 加载字体
times_new_roman_font = fm.FontProperties(fname=font_path)

def map_label(predict_str):
    """
    从预测字符串中提取类别标签（0-3）。
    假设模型输出中可能包含数字 '0','1','2','3'，按顺序匹配第一个数字。
    若未匹配到任何数字，默认返回3（可根据实际情况调整）。
    """
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认类别

# 1. 读取测试集真实标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target（0/1/2/3）
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性并截断
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 构建与画图代码兼容的数据格式（列表 of dict）
data = [{"label": t, "predict": p} for t, p in zip(true_labels, pred_labels)]

# 5. 准备ROC曲线所需数据
y_true = [int(item["label"]) for item in data]
y_pred = [int(item["predict"]) for item in data]  # 此处predict已是整数

# 将标签二值化
n_classes = 4
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])

# 类别名称映射（可根据实际修改）
class_names = {0: "non-depressed", 1: "mild", 2: "moderate", 3: "severe"}

# 计算ROC曲线和AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_pred_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类别的ROC曲线
plt.figure()
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             lw=2, label=f'{class_names[i]} (area = {roc_auc[i]:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontproperties=times_new_roman_font)
plt.ylabel('True Positive Rate', fontproperties=times_new_roman_font)
plt.title('Receiver Operating Characteristic (ROC) for each level', fontproperties=times_new_roman_font)
plt.legend(loc="lower right", prop=times_new_roman_font)

# 设置刻度字体
plt.xticks(fontproperties=times_new_roman_font)
plt.yticks(fontproperties=times_new_roman_font)

plt.savefig(output_img_path, format='png', dpi=800, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Qwen3.5-35B-A3B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-35B-A3B-Base/lora/eval_2026-03-08-20-34-30/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：按顺序查找 '0','1','2','3'，返回第一个匹配的数字，若均未找到则默认返回3"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认返回3（可调整）

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算四分类指标（使用宏平均 macro）
accuracy = accuracy_score(true_labels, pred_labels)
precision_macro = precision_score(true_labels, pred_labels, average='macro')
recall_macro = recall_score(true_labels, pred_labels, average='macro')
f1_macro = f1_score(true_labels, pred_labels, average='macro')

# 可选：加权平均
precision_weighted = precision_score(true_labels, pred_labels, average='weighted')
recall_weighted = recall_score(true_labels, pred_labels, average='weighted')
f1_weighted = f1_score(true_labels, pred_labels, average='weighted')

# 5. 打印主要结果（宏平均）
print("评估结果（宏平均 Macro）：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}%")
print(f"精确率 (Precision): {precision_macro*100:.2f}%")
print(f"召回率 (Recall): {recall_macro*100:.2f}%")
print(f"F1 值 (F1-score): {f1_macro*100:.2f}%")

# 可选：打印加权平均
print("\n评估结果（加权平均 Weighted）：")
print(f"精确率 (Precision): {precision_weighted*100:.2f}%")
print(f"召回率 (Recall): {recall_weighted*100:.2f}%")
print(f"F1 值 (F1-score): {f1_weighted*100:.2f}%")

# 可选：打印每个类别的详细指标
print("\n各类别详细指标：")
print(classification_report(true_labels, pred_labels, digits=4))
# Out:
# 评估结果（宏平均 Macro）：
# 准确率 (Accuracy): 86.72%
# 精确率 (Precision): 71.76%
# 召回率 (Recall): 66.63%
# F1 值 (F1-score): 68.70%
#
# 评估结果（加权平均 Weighted）：
# 精确率 (Precision): 85.47%
# 召回率 (Recall): 86.72%
# F1 值 (F1-score): 85.84%
#
# 各类别详细指标：
#               precision    recall  f1-score   support
#
#            0     0.9088    0.9577    0.9326      1134
#            1     0.6165    0.4457    0.5174       184
#            2     0.6415    0.5312    0.5812        64
#            3     0.7037    0.7308    0.7170        26
#
#     accuracy                         0.8672      1408
#    macro avg     0.7176    0.6663    0.6870      1408
# weighted avg     0.8547    0.8672    0.8584      1408

# %%
import json, csv
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# ================== 配置区域 ==================
# 字体路径（请确保文件存在）
font_path = '/data/zhengtianlong/ttf/timesi.ttf'
# 测试集CSV文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
# 预测结果JSONL文件路径
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-35B-A3B-Base/lora/eval_2026-03-08-20-34-30/generated_predictions.jsonl"
# 输出图片保存路径
output_img_path = "/data/zhengtianlong/Private/Depressed/result_IMG/Qwen3.5-35B-A3B-Base_ROC_curves.png"
# =============================================

# 加载字体
times_new_roman_font = fm.FontProperties(fname=font_path)

def map_label(predict_str):
    """
    从预测字符串中提取类别标签（0-3）。
    假设模型输出中可能包含数字 '0','1','2','3'，按顺序匹配第一个数字。
    若未匹配到任何数字，默认返回3（可根据实际情况调整）。
    """
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认类别

# 1. 读取测试集真实标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target（0/1/2/3）
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性并截断
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 构建与画图代码兼容的数据格式（列表 of dict）
data = [{"label": t, "predict": p} for t, p in zip(true_labels, pred_labels)]

# 5. 准备ROC曲线所需数据
y_true = [int(item["label"]) for item in data]
y_pred = [int(item["predict"]) for item in data]  # 此处predict已是整数

# 将标签二值化
n_classes = 4
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])

# 类别名称映射（可根据实际修改）
class_names = {0: "non-depressed", 1: "mild", 2: "moderate", 3: "severe"}

# 计算ROC曲线和AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_pred_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类别的ROC曲线
plt.figure()
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             lw=2, label=f'{class_names[i]} (area = {roc_auc[i]:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontproperties=times_new_roman_font)
plt.ylabel('True Positive Rate', fontproperties=times_new_roman_font)
plt.title('Receiver Operating Characteristic (ROC) for each level', fontproperties=times_new_roman_font)
plt.legend(loc="lower right", prop=times_new_roman_font)

# 设置刻度字体
plt.xticks(fontproperties=times_new_roman_font)
plt.yticks(fontproperties=times_new_roman_font)

plt.savefig(output_img_path, format='png', dpi=800, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Multilabel Classification of Depression Emotions

# %% [markdown]
# ### Qwen3.5-0.8B-Base

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-0.8B-Base/lora/eval_2026-03-10-04-50-16/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.1192
# Hamming Loss: 0.2741
#
# Macro Precision: 0.6137
# Macro Recall:    0.7291
# Macro F1-score:  0.6651
#
# Micro Precision: 0.6650
# Micro Recall:    0.7923
# Micro F1-score:  0.7231
#
# 每个类别的指标：
# anger:
#   Precision: 0.5396
#   Recall:    0.7304
#   F1-score:  0.6207
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.3161
#   Recall:    0.3216
#   F1-score:  0.3188
#   Support:   171
# emptiness:
#   Precision: 0.5974
#   Recall:    0.6833
#   F1-score:  0.6375
#   Support:   341
# hopelessness:
#   Precision: 0.7644
#   Recall:    0.9006
#   F1-score:  0.8269
#   Support:   634
# loneliness:
#   Precision: 0.6937
#   Recall:    0.7119
#   F1-score:  0.7027
#   Support:   420
# sadness:
#   Precision: 0.7976
#   Recall:    0.9613
#   F1-score:  0.8718
#   Support:   697
# suicide intent:
#   Precision: 0.5909
#   Recall:    0.7284
#   F1-score:  0.6525
#   Support:   232
# worthlessness:
#   Precision: 0.6095
#   Recall:    0.7949
# ...

# %% [markdown]
# ### Qwen3.5-2B-Base

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-2B-Base/lora/eval_2026-03-10-04-50-16/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.0993
# Hamming Loss: 0.2681
#
# Macro Precision: 0.6324
# Macro Recall:    0.6879
# Macro F1-score:  0.6561
#
# Micro Precision: 0.6834
# Micro Recall:    0.7575
# Micro F1-score:  0.7185
#
# 每个类别的指标：
# anger:
#   Precision: 0.5311
#   Recall:    0.6928
#   F1-score:  0.6013
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.3000
#   Recall:    0.2105
#   F1-score:  0.2474
#   Support:   171
# emptiness:
#   Precision: 0.5956
#   Recall:    0.6393
#   F1-score:  0.6167
#   Support:   341
# hopelessness:
#   Precision: 0.7618
#   Recall:    0.8880
#   F1-score:  0.8201
#   Support:   634
# loneliness:
#   Precision: 0.7088
#   Recall:    0.7071
#   F1-score:  0.7080
#   Support:   420
# sadness:
#   Precision: 0.7965
#   Recall:    0.9211
#   F1-score:  0.8543
#   Support:   697
# suicide intent:
#   Precision: 0.7277
#   Recall:    0.7026
#   F1-score:  0.7149
#   Support:   232
# worthlessness:
#   Precision: 0.6376
#   Recall:    0.7419
# ...

# %% [markdown]
# ### Qwen3.5-4B-Base

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-4B-Base/lora/eval_2026-03-10-04-50-16/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.1402
# Hamming Loss: 0.2497
#
# Macro Precision: 0.6558
# Macro Recall:    0.7260
# Macro F1-score:  0.6883
#
# Micro Precision: 0.7000
# Micro Recall:    0.7825
# Micro F1-score:  0.7390
#
# 每个类别的指标：
# anger:
#   Precision: 0.5875
#   Recall:    0.7101
#   F1-score:  0.6430
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.3374
#   Recall:    0.3216
#   F1-score:  0.3293
#   Support:   171
# emptiness:
#   Precision: 0.6140
#   Recall:    0.6950
#   F1-score:  0.6520
#   Support:   341
# hopelessness:
#   Precision: 0.7707
#   Recall:    0.8801
#   F1-score:  0.8218
#   Support:   634
# loneliness:
#   Precision: 0.7435
#   Recall:    0.7452
#   F1-score:  0.7444
#   Support:   420
# sadness:
#   Precision: 0.8127
#   Recall:    0.9340
#   F1-score:  0.8692
#   Support:   697
# suicide intent:
#   Precision: 0.7418
#   Recall:    0.7802
#   F1-score:  0.7605
#   Support:   232
# worthlessness:
#   Precision: 0.6389
#   Recall:    0.7419
# ...

# %% [markdown]
# ### Qwen3.5-9B-Base

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-9B-Base/lora/eval_2026-03-10-04-50-16/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.1468
# Hamming Loss: 0.2490
#
# Macro Precision: 0.6648
# Macro Recall:    0.6810
# Macro F1-score:  0.6707
#
# Micro Precision: 0.7152
# Micro Recall:    0.7456
# Micro F1-score:  0.7301
#
# 每个类别的指标：
# anger:
#   Precision: 0.6228
#   Recall:    0.7130
#   F1-score:  0.6649
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.3000
#   Recall:    0.2105
#   F1-score:  0.2474
#   Support:   171
# emptiness:
#   Precision: 0.6296
#   Recall:    0.6481
#   F1-score:  0.6387
#   Support:   341
# hopelessness:
#   Precision: 0.7817
#   Recall:    0.8470
#   F1-score:  0.8130
#   Support:   634
# loneliness:
#   Precision: 0.7422
#   Recall:    0.7333
#   F1-score:  0.7377
#   Support:   420
# sadness:
#   Precision: 0.8156
#   Recall:    0.9139
#   F1-score:  0.8620
#   Support:   697
# suicide intent:
#   Precision: 0.7857
#   Recall:    0.7112
#   F1-score:  0.7466
#   Support:   232
# worthlessness:
#   Precision: 0.6410
#   Recall:    0.6705
# ...

# %% [markdown]
# ### Qwen3.5-35B-A3B-Base

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-35B-A3B-Base/lora/eval_2026-03-10-04-50-16/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.1512
# Hamming Loss: 0.2437
#
# Macro Precision: 0.6694
# Macro Recall:    0.6936
# Macro F1-score:  0.6783
#
# Micro Precision: 0.7169
# Micro Recall:    0.7611
# Micro F1-score:  0.7384
#
# 每个类别的指标：
# anger:
#   Precision: 0.5877
#   Recall:    0.7188
#   F1-score:  0.6467
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.3417
#   Recall:    0.2398
#   F1-score:  0.2818
#   Support:   171
# emptiness:
#   Precision: 0.6288
#   Recall:    0.6012
#   F1-score:  0.6147
#   Support:   341
# hopelessness:
#   Precision: 0.7920
#   Recall:    0.8770
#   F1-score:  0.8323
#   Support:   634
# loneliness:
#   Precision: 0.7679
#   Recall:    0.7405
#   F1-score:  0.7539
#   Support:   420
# sadness:
#   Precision: 0.8131
#   Recall:    0.9426
#   F1-score:  0.8731
#   Support:   697
# suicide intent:
#   Precision: 0.7850
#   Recall:    0.7241
#   F1-score:  0.7534
#   Support:   232
# worthlessness:
#   Precision: 0.6388
#   Recall:    0.7051
# ...

# %% [markdown]
# ## Multi-task2_8-enhance

# %% [markdown]
# ### Qwen3.5-0.8B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test_binary.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-0.8B-Base/lora/eval_2026-03-12-09-33-16_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：如果包含 '0' 返回0，否则如果包含 '1' 返回1，否则默认返回1"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    else:
        return 1  # 默认返回1

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        # target 可能为字符串 '0' 或 '1'，转为整数
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算指标
accuracy = accuracy_score(true_labels, pred_labels)
precision = precision_score(true_labels, pred_labels, pos_label=1) # pos_label=1 指定正类为抑郁（1）
recall = recall_score(true_labels, pred_labels, pos_label=1)
f1 = f1_score(true_labels, pred_labels, pos_label=1)

# 5. 打印结果
print("评估结果：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}")
print(f"精确率 (Precision): {precision*100:.2f}")
print(f"召回率 (Recall): {recall*100:.2f}")
print(f"F1 值 (F1-score): {f1*100:.2f}")
# Out:
# 评估结果：
# 准确率 (Accuracy): 87.29
# 精确率 (Precision): 70.56
# 召回率 (Recall): 59.49
# F1 值 (F1-score): 64.55

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-0.8B-Base/lora/eval_2026-03-12-09-33-16_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.1932
# Hamming Loss: 0.2105
#
# Macro Precision: 0.7165
# Macro Recall:    0.7305
# Macro F1-score:  0.7214
#
# Micro Precision: 0.7550
# Micro Recall:    0.7905
# Micro F1-score:  0.7723
#
# 每个类别的指标：
# anger:
#   Precision: 0.6361
#   Recall:    0.7043
#   F1-score:  0.6685
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.4286
#   Recall:    0.3333
#   F1-score:  0.3750
#   Support:   171
# emptiness:
#   Precision: 0.7331
#   Recall:    0.7331
#   F1-score:  0.7331
#   Support:   341
# hopelessness:
#   Precision: 0.8229
#   Recall:    0.8943
#   F1-score:  0.8571
#   Support:   634
# loneliness:
#   Precision: 0.8063
#   Recall:    0.7929
#   F1-score:  0.7995
#   Support:   420
# sadness:
#   Precision: 0.8176
#   Recall:    0.9326
#   F1-score:  0.8713
#   Support:   697
# suicide intent:
#   Precision: 0.7961
#   Recall:    0.7069
#   F1-score:  0.7489
#   Support:   232
# worthlessness:
#   Precision: 0.6908
#   Recall:    0.7465
# ...

# %% [markdown]
# ### Qwen3.5-2B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test_binary.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-2B-Base/lora/eval_2026-03-12-09-33-16_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：如果包含 '0' 返回0，否则如果包含 '1' 返回1，否则默认返回1"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    else:
        return 1  # 默认返回1

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        # target 可能为字符串 '0' 或 '1'，转为整数
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算指标
accuracy = accuracy_score(true_labels, pred_labels)
precision = precision_score(true_labels, pred_labels, pos_label=1) # pos_label=1 指定正类为抑郁（1）
recall = recall_score(true_labels, pred_labels, pos_label=1)
f1 = f1_score(true_labels, pred_labels, pos_label=1)

# 5. 打印结果
print("评估结果：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}")
print(f"精确率 (Precision): {precision*100:.2f}")
print(f"召回率 (Recall): {recall*100:.2f}")
print(f"F1 值 (F1-score): {f1*100:.2f}")
# Out:
# 评估结果：
# 准确率 (Accuracy): 87.86
# 精确率 (Precision): 71.73
# 召回率 (Recall): 62.04
# F1 值 (F1-score): 66.54

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-2B-Base/lora/eval_2026-03-12-09-33-16_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.2075
# Hamming Loss: 0.2072
#
# Macro Precision: 0.7249
# Macro Recall:    0.7284
# Macro F1-score:  0.7244
#
# Micro Precision: 0.7610
# Micro Recall:    0.7889
# Micro F1-score:  0.7747
#
# 每个类别的指标：
# anger:
#   Precision: 0.6712
#   Recall:    0.7159
#   F1-score:  0.6928
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.4104
#   Recall:    0.3216
#   F1-score:  0.3607
#   Support:   171
# emptiness:
#   Precision: 0.7432
#   Recall:    0.7214
#   F1-score:  0.7321
#   Support:   341
# hopelessness:
#   Precision: 0.8192
#   Recall:    0.9006
#   F1-score:  0.8580
#   Support:   634
# loneliness:
#   Precision: 0.7990
#   Recall:    0.7667
#   F1-score:  0.7825
#   Support:   420
# sadness:
#   Precision: 0.8142
#   Recall:    0.9369
#   F1-score:  0.8712
#   Support:   697
# suicide intent:
#   Precision: 0.8442
#   Recall:    0.7241
#   F1-score:  0.7796
#   Support:   232
# worthlessness:
#   Precision: 0.6978
#   Recall:    0.7396
# ...

# %% [markdown]
# ### Qwen3.5-4B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test_binary.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-4B-Base/lora/eval_2026-03-12-09-33-16_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：如果包含 '0' 返回0，否则如果包含 '1' 返回1，否则默认返回1"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    else:
        return 1  # 默认返回1

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        # target 可能为字符串 '0' 或 '1'，转为整数
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算指标
accuracy = accuracy_score(true_labels, pred_labels)
precision = precision_score(true_labels, pred_labels, pos_label=1) # pos_label=1 指定正类为抑郁（1）
recall = recall_score(true_labels, pred_labels, pos_label=1)
f1 = f1_score(true_labels, pred_labels, pos_label=1)

# 5. 打印结果
print("评估结果：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}")
print(f"精确率 (Precision): {precision*100:.2f}")
print(f"召回率 (Recall): {recall*100:.2f}")
print(f"F1 值 (F1-score): {f1*100:.2f}")
# Out:
# 评估结果：
# 准确率 (Accuracy): 87.57
# 精确率 (Precision): 71.81
# 召回率 (Recall): 59.49
# F1 值 (F1-score): 65.07

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-4B-Base/lora/eval_2026-03-12-09-33-16_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.2494
# Hamming Loss: 0.1843
#
# Macro Precision: 0.7518
# Macro Recall:    0.7637
# Macro F1-score:  0.7569
#
# Micro Precision: 0.7865
# Micro Recall:    0.8125
# Micro F1-score:  0.7993
#
# 每个类别的指标：
# anger:
#   Precision: 0.7182
#   Recall:    0.7536
#   F1-score:  0.7355
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.4570
#   Recall:    0.4035
#   F1-score:  0.4286
#   Support:   171
# emptiness:
#   Precision: 0.7435
#   Recall:    0.7566
#   F1-score:  0.7500
#   Support:   341
# hopelessness:
#   Precision: 0.8286
#   Recall:    0.8770
#   F1-score:  0.8521
#   Support:   634
# loneliness:
#   Precision: 0.8492
#   Recall:    0.8048
#   F1-score:  0.8264
#   Support:   420
# sadness:
#   Precision: 0.8540
#   Recall:    0.9397
#   F1-score:  0.8948
#   Support:   697
# suicide intent:
#   Precision: 0.8318
#   Recall:    0.7888
#   F1-score:  0.8097
#   Support:   232
# worthlessness:
#   Precision: 0.7318
#   Recall:    0.7857
# ...

# %% [markdown]
# ### Qwen3.5-9B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test_binary.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-9B-Base/lora/eval_2026-03-12-09-33-16_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：如果包含 '0' 返回0，否则如果包含 '1' 返回1，否则默认返回1"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    else:
        return 1  # 默认返回1

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        # target 可能为字符串 '0' 或 '1'，转为整数
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算指标
accuracy = accuracy_score(true_labels, pred_labels)
precision = precision_score(true_labels, pred_labels, pos_label=1) # pos_label=1 指定正类为抑郁（1）
recall = recall_score(true_labels, pred_labels, pos_label=1)
f1 = f1_score(true_labels, pred_labels, pos_label=1)

# 5. 打印结果
print("评估结果：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}")
print(f"精确率 (Precision): {precision*100:.2f}")
print(f"召回率 (Recall): {recall*100:.2f}")
print(f"F1 值 (F1-score): {f1*100:.2f}")
# Out:
# 评估结果：
# 准确率 (Accuracy): 88.28
# 精确率 (Precision): 72.61
# 召回率 (Recall): 63.87
# F1 值 (F1-score): 67.96

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-9B-Base/lora/eval_2026-03-12-09-33-16_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.2494
# Hamming Loss: 0.1838
#
# Macro Precision: 0.7563
# Macro Recall:    0.7525
# Macro F1-score:  0.7527
#
# Micro Precision: 0.7914
# Micro Recall:    0.8054
# Micro F1-score:  0.7984
#
# 每个类别的指标：
# anger:
#   Precision: 0.7011
#   Recall:    0.7275
#   F1-score:  0.7141
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.4803
#   Recall:    0.3567
#   F1-score:  0.4094
#   Support:   171
# emptiness:
#   Precision: 0.7807
#   Recall:    0.7830
#   F1-score:  0.7818
#   Support:   341
# hopelessness:
#   Precision: 0.8475
#   Recall:    0.8675
#   F1-score:  0.8574
#   Support:   634
# loneliness:
#   Precision: 0.8177
#   Recall:    0.8119
#   F1-score:  0.8148
#   Support:   420
# sadness:
#   Precision: 0.8497
#   Recall:    0.9412
#   F1-score:  0.8931
#   Support:   697
# suicide intent:
#   Precision: 0.8429
#   Recall:    0.7629
#   F1-score:  0.8009
#   Support:   232
# worthlessness:
#   Precision: 0.7309
#   Recall:    0.7696
# ...

# %% [markdown]
# ### Qwen3.5-35B-A3B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test_binary.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-35B-A3B-Base/lora/eval_2026-03-12-09-33-16_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：如果包含 '0' 返回0，否则如果包含 '1' 返回1，否则默认返回1"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    else:
        return 1  # 默认返回1

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        # target 可能为字符串 '0' 或 '1'，转为整数
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算指标
accuracy = accuracy_score(true_labels, pred_labels)
precision = precision_score(true_labels, pred_labels, pos_label=1)
recall = recall_score(true_labels, pred_labels, pos_label=1)
f1 = f1_score(true_labels, pred_labels, pos_label=1)

# 5. 打印结果
print("评估结果：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}")
print(f"精确率 (Precision): {precision*100:.2f}")
print(f"召回率 (Recall): {recall*100:.2f}")
print(f"F1 值 (F1-score): {f1*100:.2f}")
# Out:
# 评估结果：
# 准确率 (Accuracy): 88.92
# 精确率 (Precision): 75.00
# 召回率 (Recall): 64.60
# F1 值 (F1-score): 69.41

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-35B-A3B-Base/lora/eval_2026-03-12-09-33-16_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.2130
# Hamming Loss: 0.2016
#
# Macro Precision: 0.7415
# Macro Recall:    0.7228
# Macro F1-score:  0.7304
#
# Micro Precision: 0.7787
# Micro Recall:    0.7737
# Micro F1-score:  0.7762
#
# 每个类别的指标：
# anger:
#   Precision: 0.6849
#   Recall:    0.7246
#   F1-score:  0.7042
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.4609
#   Recall:    0.3450
#   F1-score:  0.3946
#   Support:   171
# emptiness:
#   Precision: 0.7340
#   Recall:    0.6716
#   F1-score:  0.7014
#   Support:   341
# hopelessness:
#   Precision: 0.8379
#   Recall:    0.8233
#   F1-score:  0.8305
#   Support:   634
# loneliness:
#   Precision: 0.8195
#   Recall:    0.7786
#   F1-score:  0.7985
#   Support:   420
# sadness:
#   Precision: 0.8536
#   Recall:    0.9283
#   F1-score:  0.8893
#   Support:   697
# suicide intent:
#   Precision: 0.8372
#   Recall:    0.7759
#   F1-score:  0.8054
#   Support:   232
# worthlessness:
#   Precision: 0.7042
#   Recall:    0.7350
# ...

# %% [markdown]
# ## Multi-task4_8-enhance

# %% [markdown]
# ### Qwen3.5-0.8B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-0.8B-Base/lora/eval_2026-03-11-03-48-30_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：按顺序查找 '0','1','2','3'，返回第一个匹配的数字，若均未找到则默认返回3"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认返回3（可调整）

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算四分类指标（使用宏平均 macro）
accuracy = accuracy_score(true_labels, pred_labels)
precision_macro = precision_score(true_labels, pred_labels, average='macro')
recall_macro = recall_score(true_labels, pred_labels, average='macro')
f1_macro = f1_score(true_labels, pred_labels, average='macro')

# 可选：加权平均
precision_weighted = precision_score(true_labels, pred_labels, average='weighted')
recall_weighted = recall_score(true_labels, pred_labels, average='weighted')
f1_weighted = f1_score(true_labels, pred_labels, average='weighted')

# 5. 打印主要结果（宏平均）
print("评估结果（宏平均 Macro）：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}%")
print(f"精确率 (Precision): {precision_macro*100:.2f}%")
print(f"召回率 (Recall): {recall_macro*100:.2f}%")
print(f"F1 值 (F1-score): {f1_macro*100:.2f}%")

# 可选：打印加权平均
print("\n评估结果（加权平均 Weighted）：")
print(f"精确率 (Precision): {precision_weighted*100:.2f}%")
print(f"召回率 (Recall): {recall_weighted*100:.2f}%")
print(f"F1 值 (F1-score): {f1_weighted*100:.2f}%")

# 可选：打印每个类别的详细指标
print("\n各类别详细指标：")
print(classification_report(true_labels, pred_labels, digits=4))
# Out:
# 评估结果（宏平均 Macro）：
# 准确率 (Accuracy): 83.03%
# 精确率 (Precision): 59.50%
# 召回率 (Recall): 51.68%
# F1 值 (F1-score): 54.76%
#
# 评估结果（加权平均 Weighted）：
# 精确率 (Precision): 80.92%
# 召回率 (Recall): 83.03%
# F1 值 (F1-score): 81.76%
#
# 各类别详细指标：
#               precision    recall  f1-score   support
#
#            0     0.8948    0.9453    0.9194      1134
#            1     0.4575    0.3804    0.4154       184
#            2     0.3611    0.2031    0.2600        64
#            3     0.6667    0.5385    0.5957        26
#
#     accuracy                         0.8303      1408
#    macro avg     0.5950    0.5168    0.5476      1408
# weighted avg     0.8092    0.8303    0.8176      1408

# %%
import json, csv
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# ================== 配置区域 ==================
# 字体路径（请确保文件存在）
font_path = '/data/zhengtianlong/ttf/timesi.ttf'
# 测试集CSV文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
# 预测结果JSONL文件路径
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-0.8B-Base/lora/eval_2026-03-11-03-48-30_1/generated_predictions.jsonl"
# 输出图片保存路径
output_img_path = "/data/zhengtianlong/Private/Depressed/result_IMG/Qwen3.5-0.8B-Base_Multi_ROC_curves.png"
# =============================================

# 加载字体
times_new_roman_font = fm.FontProperties(fname=font_path)

def map_label(predict_str):
    """
    从预测字符串中提取类别标签（0-3）。
    假设模型输出中可能包含数字 '0','1','2','3'，按顺序匹配第一个数字。
    若未匹配到任何数字，默认返回3（可根据实际情况调整）。
    """
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认类别

# 1. 读取测试集真实标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target（0/1/2/3）
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性并截断
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 构建与画图代码兼容的数据格式（列表 of dict）
data = [{"label": t, "predict": p} for t, p in zip(true_labels, pred_labels)]

# 5. 准备ROC曲线所需数据
y_true = [int(item["label"]) for item in data]
y_pred = [int(item["predict"]) for item in data]  # 此处predict已是整数

# 将标签二值化
n_classes = 4
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])

# 类别名称映射（可根据实际修改）
class_names = {0: "non-depressed", 1: "mild", 2: "moderate", 3: "severe"}

# 计算ROC曲线和AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_pred_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类别的ROC曲线
plt.figure()
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             lw=2, label=f'{class_names[i]} (area = {roc_auc[i]:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontproperties=times_new_roman_font)
plt.ylabel('True Positive Rate', fontproperties=times_new_roman_font)
plt.title('Receiver Operating Characteristic (ROC) for each level', fontproperties=times_new_roman_font)
plt.legend(loc="lower right", prop=times_new_roman_font)

# 设置刻度字体
plt.xticks(fontproperties=times_new_roman_font)
plt.yticks(fontproperties=times_new_roman_font)

plt.savefig(output_img_path, format='png', dpi=800, bbox_inches='tight')
plt.show()

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-0.8B-Base/lora/eval_2026-03-11-03-48-30_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.1876
# Hamming Loss: 0.2072
#
# Macro Precision: 0.7190
# Macro Recall:    0.7348
# Macro F1-score:  0.7246
#
# Micro Precision: 0.7585
# Micro Recall:    0.7941
# Micro F1-score:  0.7759
#
# 每个类别的指标：
# anger:
#   Precision: 0.6631
#   Recall:    0.7188
#   F1-score:  0.6898
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.4400
#   Recall:    0.3216
#   F1-score:  0.3716
#   Support:   171
# emptiness:
#   Precision: 0.7321
#   Recall:    0.7214
#   F1-score:  0.7267
#   Support:   341
# hopelessness:
#   Precision: 0.8210
#   Recall:    0.8896
#   F1-score:  0.8539
#   Support:   634
# loneliness:
#   Precision: 0.8186
#   Recall:    0.8167
#   F1-score:  0.8176
#   Support:   420
# sadness:
#   Precision: 0.8181
#   Recall:    0.9225
#   F1-score:  0.8672
#   Support:   697
# suicide intent:
#   Precision: 0.7685
#   Recall:    0.7155
#   F1-score:  0.7411
#   Support:   232
# worthlessness:
#   Precision: 0.6907
#   Recall:    0.7719
# ...

# %% [markdown]
# ### Qwen3.5-2B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-2B-Base/lora/eval_2026-03-11-03-48-30_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：按顺序查找 '0','1','2','3'，返回第一个匹配的数字，若均未找到则默认返回3"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认返回3（可调整）

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算四分类指标（使用宏平均 macro）
accuracy = accuracy_score(true_labels, pred_labels)
precision_macro = precision_score(true_labels, pred_labels, average='macro')
recall_macro = recall_score(true_labels, pred_labels, average='macro')
f1_macro = f1_score(true_labels, pred_labels, average='macro')

# 可选：加权平均
precision_weighted = precision_score(true_labels, pred_labels, average='weighted')
recall_weighted = recall_score(true_labels, pred_labels, average='weighted')
f1_weighted = f1_score(true_labels, pred_labels, average='weighted')

# 5. 打印主要结果（宏平均）
print("评估结果（宏平均 Macro）：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}%")
print(f"精确率 (Precision): {precision_macro*100:.2f}%")
print(f"召回率 (Recall): {recall_macro*100:.2f}%")
print(f"F1 值 (F1-score): {f1_macro*100:.2f}%")

# 可选：打印加权平均
print("\n评估结果（加权平均 Weighted）：")
print(f"精确率 (Precision): {precision_weighted*100:.2f}%")
print(f"召回率 (Recall): {recall_weighted*100:.2f}%")
print(f"F1 值 (F1-score): {f1_weighted*100:.2f}%")

# 可选：打印每个类别的详细指标
print("\n各类别详细指标：")
print(classification_report(true_labels, pred_labels, digits=4))
# Out:
# 评估结果（宏平均 Macro）：
# 准确率 (Accuracy): 83.45%
# 精确率 (Precision): 55.94%
# 召回率 (Recall): 52.04%
# F1 值 (F1-score): 53.31%
#
# 评估结果（加权平均 Weighted）：
# 精确率 (Precision): 81.46%
# 召回率 (Recall): 83.45%
# F1 值 (F1-score): 82.25%
#
# 各类别详细指标：
#               precision    recall  f1-score   support
#
#            0     0.9027    0.9489    0.9252      1134
#            1     0.4737    0.3913    0.4286       184
#            2     0.3611    0.2031    0.2600        64
#            3     0.5000    0.5385    0.5185        26
#
#     accuracy                         0.8345      1408
#    macro avg     0.5594    0.5204    0.5331      1408
# weighted avg     0.8146    0.8345    0.8225      1408

# %%
import json, csv
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# ================== 配置区域 ==================
# 字体路径（请确保文件存在）
font_path = '/data/zhengtianlong/ttf/timesi.ttf'
# 测试集CSV文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
# 预测结果JSONL文件路径
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-2B-Base/lora/eval_2026-03-11-03-48-30_1/generated_predictions.jsonl"
# 输出图片保存路径
output_img_path = "/data/zhengtianlong/Private/Depressed/result_IMG/Qwen3.5-2B-Base_Multi_ROC_curves.png"
# =============================================

# 加载字体
times_new_roman_font = fm.FontProperties(fname=font_path)

def map_label(predict_str):
    """
    从预测字符串中提取类别标签（0-3）。
    假设模型输出中可能包含数字 '0','1','2','3'，按顺序匹配第一个数字。
    若未匹配到任何数字，默认返回3（可根据实际情况调整）。
    """
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认类别

# 1. 读取测试集真实标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target（0/1/2/3）
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性并截断
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 构建与画图代码兼容的数据格式（列表 of dict）
data = [{"label": t, "predict": p} for t, p in zip(true_labels, pred_labels)]

# 5. 准备ROC曲线所需数据
y_true = [int(item["label"]) for item in data]
y_pred = [int(item["predict"]) for item in data]  # 此处predict已是整数

# 将标签二值化
n_classes = 4
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])

# 类别名称映射（可根据实际修改）
class_names = {0: "non-depressed", 1: "mild", 2: "moderate", 3: "severe"}

# 计算ROC曲线和AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_pred_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类别的ROC曲线
plt.figure()
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             lw=2, label=f'{class_names[i]} (area = {roc_auc[i]:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontproperties=times_new_roman_font)
plt.ylabel('True Positive Rate', fontproperties=times_new_roman_font)
plt.title('Receiver Operating Characteristic (ROC) for each level', fontproperties=times_new_roman_font)
plt.legend(loc="lower right", prop=times_new_roman_font)

# 设置刻度字体
plt.xticks(fontproperties=times_new_roman_font)
plt.yticks(fontproperties=times_new_roman_font)

plt.savefig(output_img_path, format='png', dpi=800, bbox_inches='tight')
plt.show()

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-2B-Base/lora/eval_2026-03-11-03-48-30_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.2031
# Hamming Loss: 0.2041
#
# Macro Precision: 0.7277
# Macro Recall:    0.7365
# Macro F1-score:  0.7298
#
# Micro Precision: 0.7636
# Micro Recall:    0.7941
# Micro F1-score:  0.7786
#
# 每个类别的指标：
# anger:
#   Precision: 0.6782
#   Recall:    0.7391
#   F1-score:  0.7074
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.4385
#   Recall:    0.3333
#   F1-score:  0.3787
#   Support:   171
# emptiness:
#   Precision: 0.7227
#   Recall:    0.7566
#   F1-score:  0.7393
#   Support:   341
# hopelessness:
#   Precision: 0.8341
#   Recall:    0.8880
#   F1-score:  0.8602
#   Support:   634
# loneliness:
#   Precision: 0.7866
#   Recall:    0.7810
#   F1-score:  0.7838
#   Support:   420
# sadness:
#   Precision: 0.8229
#   Recall:    0.9397
#   F1-score:  0.8774
#   Support:   697
# suicide intent:
#   Precision: 0.8450
#   Recall:    0.7284
#   F1-score:  0.7824
#   Support:   232
# worthlessness:
#   Precision: 0.6938
#   Recall:    0.7258
# ...

# %% [markdown]
# ### Qwen3.5-4B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-4B-Base/lora/eval_2026-03-11-03-48-30_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：按顺序查找 '0','1','2','3'，返回第一个匹配的数字，若均未找到则默认返回3"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认返回3（可调整）

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算四分类指标（使用宏平均 macro）
accuracy = accuracy_score(true_labels, pred_labels)
precision_macro = precision_score(true_labels, pred_labels, average='macro')
recall_macro = recall_score(true_labels, pred_labels, average='macro')
f1_macro = f1_score(true_labels, pred_labels, average='macro')

# 可选：加权平均
precision_weighted = precision_score(true_labels, pred_labels, average='weighted')
recall_weighted = recall_score(true_labels, pred_labels, average='weighted')
f1_weighted = f1_score(true_labels, pred_labels, average='weighted')

# 5. 打印主要结果（宏平均）
print("评估结果（宏平均 Macro）：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}%")
print(f"精确率 (Precision): {precision_macro*100:.2f}%")
print(f"召回率 (Recall): {recall_macro*100:.2f}%")
print(f"F1 值 (F1-score): {f1_macro*100:.2f}%")

# 可选：打印加权平均
print("\n评估结果（加权平均 Weighted）：")
print(f"精确率 (Precision): {precision_weighted*100:.2f}%")
print(f"召回率 (Recall): {recall_weighted*100:.2f}%")
print(f"F1 值 (F1-score): {f1_weighted*100:.2f}%")

# 可选：打印每个类别的详细指标
print("\n各类别详细指标：")
print(classification_report(true_labels, pred_labels, digits=4))
# Out:
# 评估结果（宏平均 Macro）：
# 准确率 (Accuracy): 83.59%
# 精确率 (Precision): 61.58%
# 召回率 (Recall): 55.67%
# F1 值 (F1-score): 58.18%
#
# 评估结果（加权平均 Weighted）：
# 精确率 (Precision): 81.75%
# 召回率 (Recall): 83.59%
# F1 值 (F1-score): 82.52%
#
# 各类别详细指标：
#               precision    recall  f1-score   support
#
#            0     0.9034    0.9480    0.9251      1134
#            1     0.4570    0.3750    0.4119       184
#            2     0.3636    0.2500    0.2963        64
#            3     0.7391    0.6538    0.6939        26
#
#     accuracy                         0.8359      1408
#    macro avg     0.6158    0.5567    0.5818      1408
# weighted avg     0.8175    0.8359    0.8252      1408

# %%
import json, csv
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# ================== 配置区域 ==================
# 字体路径（请确保文件存在）
font_path = '/data/zhengtianlong/ttf/timesi.ttf'
# 测试集CSV文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
# 预测结果JSONL文件路径
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-4B-Base/lora/eval_2026-03-11-03-48-30_1/generated_predictions.jsonl"
# 输出图片保存路径
output_img_path = "/data/zhengtianlong/Private/Depressed/result_IMG/Qwen3.5-4B-Base_Multi_ROC_curves.png"
# =============================================

# 加载字体
times_new_roman_font = fm.FontProperties(fname=font_path)

def map_label(predict_str):
    """
    从预测字符串中提取类别标签（0-3）。
    假设模型输出中可能包含数字 '0','1','2','3'，按顺序匹配第一个数字。
    若未匹配到任何数字，默认返回3（可根据实际情况调整）。
    """
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认类别

# 1. 读取测试集真实标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target（0/1/2/3）
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性并截断
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 构建与画图代码兼容的数据格式（列表 of dict）
data = [{"label": t, "predict": p} for t, p in zip(true_labels, pred_labels)]

# 5. 准备ROC曲线所需数据
y_true = [int(item["label"]) for item in data]
y_pred = [int(item["predict"]) for item in data]  # 此处predict已是整数

# 将标签二值化
n_classes = 4
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])

# 类别名称映射（可根据实际修改）
class_names = {0: "non-depressed", 1: "mild", 2: "moderate", 3: "severe"}

# 计算ROC曲线和AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_pred_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类别的ROC曲线
plt.figure()
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             lw=2, label=f'{class_names[i]} (area = {roc_auc[i]:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontproperties=times_new_roman_font)
plt.ylabel('True Positive Rate', fontproperties=times_new_roman_font)
plt.title('Receiver Operating Characteristic (ROC) for each level', fontproperties=times_new_roman_font)
plt.legend(loc="lower right", prop=times_new_roman_font)

# 设置刻度字体
plt.xticks(fontproperties=times_new_roman_font)
plt.yticks(fontproperties=times_new_roman_font)

plt.savefig(output_img_path, format='png', dpi=800, bbox_inches='tight')
plt.show()

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-4B-Base/lora/eval_2026-03-11-03-48-30_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.2483
# Hamming Loss: 0.1874
#
# Macro Precision: 0.7462
# Macro Recall:    0.7555
# Macro F1-score:  0.7498
#
# Micro Precision: 0.7839
# Micro Recall:    0.8079
# Micro F1-score:  0.7957
#
# 每个类别的指标：
# anger:
#   Precision: 0.7051
#   Recall:    0.7623
#   F1-score:  0.7326
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.4122
#   Recall:    0.3567
#   F1-score:  0.3824
#   Support:   171
# emptiness:
#   Precision: 0.7582
#   Recall:    0.7449
#   F1-score:  0.7515
#   Support:   341
# hopelessness:
#   Precision: 0.8308
#   Recall:    0.8675
#   F1-score:  0.8488
#   Support:   634
# loneliness:
#   Precision: 0.8481
#   Recall:    0.7976
#   F1-score:  0.8221
#   Support:   420
# sadness:
#   Precision: 0.8509
#   Recall:    0.9498
#   F1-score:  0.8976
#   Support:   697
# suicide intent:
#   Precision: 0.8394
#   Recall:    0.7888
#   F1-score:  0.8133
#   Support:   232
# worthlessness:
#   Precision: 0.7247
#   Recall:    0.7765
# ...

# %% [markdown]
# ### Qwen3.5-9B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-9B-Base/lora/eval_2026-03-11-03-48-30_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：按顺序查找 '0','1','2','3'，返回第一个匹配的数字，若均未找到则默认返回3"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认返回3（可调整）

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算四分类指标（使用宏平均 macro）
accuracy = accuracy_score(true_labels, pred_labels)
precision_macro = precision_score(true_labels, pred_labels, average='macro')
recall_macro = recall_score(true_labels, pred_labels, average='macro')
f1_macro = f1_score(true_labels, pred_labels, average='macro')

# 可选：加权平均
precision_weighted = precision_score(true_labels, pred_labels, average='weighted')
recall_weighted = recall_score(true_labels, pred_labels, average='weighted')
f1_weighted = f1_score(true_labels, pred_labels, average='weighted')

# 5. 打印主要结果（宏平均）
print("评估结果（宏平均 Macro）：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}%")
print(f"精确率 (Precision): {precision_macro*100:.2f}%")
print(f"召回率 (Recall): {recall_macro*100:.2f}%")
print(f"F1 值 (F1-score): {f1_macro*100:.2f}%")

# 可选：打印加权平均
print("\n评估结果（加权平均 Weighted）：")
print(f"精确率 (Precision): {precision_weighted*100:.2f}%")
print(f"召回率 (Recall): {recall_weighted*100:.2f}%")
print(f"F1 值 (F1-score): {f1_weighted*100:.2f}%")

# 可选：打印每个类别的详细指标
print("\n各类别详细指标：")
print(classification_report(true_labels, pred_labels, digits=4))
# Out:
# 评估结果（宏平均 Macro）：
# 准确率 (Accuracy): 84.52%
# 精确率 (Precision): 63.54%
# 召回率 (Recall): 58.69%
# F1 值 (F1-score): 60.71%
#
# 评估结果（加权平均 Weighted）：
# 精确率 (Precision): 82.99%
# 召回率 (Recall): 84.52%
# F1 值 (F1-score): 83.63%
#
# 各类别详细指标：
#               precision    recall  f1-score   support
#
#            0     0.9120    0.9506    0.9309      1134
#            1     0.4777    0.4076    0.4399       184
#            2     0.4318    0.2969    0.3519        64
#            3     0.7200    0.6923    0.7059        26
#
#     accuracy                         0.8452      1408
#    macro avg     0.6354    0.5869    0.6071      1408
# weighted avg     0.8299    0.8452    0.8363      1408

# %%
import json, csv
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# ================== 配置区域 ==================
# 字体路径（请确保文件存在）
font_path = '/data/zhengtianlong/ttf/timesi.ttf'
# 测试集CSV文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
# 预测结果JSONL文件路径
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-9B-Base/lora/eval_2026-03-11-03-48-30_1/generated_predictions.jsonl"
# 输出图片保存路径
output_img_path = "/data/zhengtianlong/Private/Depressed/result_IMG/Qwen3.5-9B-Base_Multi_ROC_curves.png"
# =============================================

# 加载字体
times_new_roman_font = fm.FontProperties(fname=font_path)

def map_label(predict_str):
    """
    从预测字符串中提取类别标签（0-3）。
    假设模型输出中可能包含数字 '0','1','2','3'，按顺序匹配第一个数字。
    若未匹配到任何数字，默认返回3（可根据实际情况调整）。
    """
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认类别

# 1. 读取测试集真实标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target（0/1/2/3）
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性并截断
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 构建与画图代码兼容的数据格式（列表 of dict）
data = [{"label": t, "predict": p} for t, p in zip(true_labels, pred_labels)]

# 5. 准备ROC曲线所需数据
y_true = [int(item["label"]) for item in data]
y_pred = [int(item["predict"]) for item in data]  # 此处predict已是整数

# 将标签二值化
n_classes = 4
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])

# 类别名称映射（可根据实际修改）
class_names = {0: "non-depressed", 1: "mild", 2: "moderate", 3: "severe"}

# 计算ROC曲线和AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_pred_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类别的ROC曲线
plt.figure()
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             lw=2, label=f'{class_names[i]} (area = {roc_auc[i]:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontproperties=times_new_roman_font)
plt.ylabel('True Positive Rate', fontproperties=times_new_roman_font)
plt.title('Receiver Operating Characteristic (ROC) for each level', fontproperties=times_new_roman_font)
plt.legend(loc="lower right", prop=times_new_roman_font)

# 设置刻度字体
plt.xticks(fontproperties=times_new_roman_font)
plt.yticks(fontproperties=times_new_roman_font)

plt.savefig(output_img_path, format='png', dpi=800, bbox_inches='tight')
plt.show()

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-9B-Base/lora/eval_2026-03-11-03-48-30_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.2494
# Hamming Loss: 0.1885
#
# Macro Precision: 0.7522
# Macro Recall:    0.7515
# Macro F1-score:  0.7498
#
# Micro Precision: 0.7848
# Micro Recall:    0.8030
# Micro F1-score:  0.7938
#
# 每个类别的指标：
# anger:
#   Precision: 0.6954
#   Recall:    0.7478
#   F1-score:  0.7207
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.5280
#   Recall:    0.3860
#   F1-score:  0.4459
#   Support:   171
# emptiness:
#   Precision: 0.7436
#   Recall:    0.7654
#   F1-score:  0.7543
#   Support:   341
# hopelessness:
#   Precision: 0.8371
#   Recall:    0.8754
#   F1-score:  0.8558
#   Support:   634
# loneliness:
#   Precision: 0.8342
#   Recall:    0.8024
#   F1-score:  0.8180
#   Support:   420
# sadness:
#   Precision: 0.8475
#   Recall:    0.9412
#   F1-score:  0.8919
#   Support:   697
# suicide intent:
#   Precision: 0.8140
#   Recall:    0.7543
#   F1-score:  0.7830
#   Support:   232
# worthlessness:
#   Precision: 0.7181
#   Recall:    0.7396
# ...

# %% [markdown]
# ### Qwen3.5-35B-A3B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-35B-A3B-Base/lora/eval_2026-03-11-03-48-30_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：按顺序查找 '0','1','2','3'，返回第一个匹配的数字，若均未找到则默认返回3"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认返回3（可调整）

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算四分类指标（使用宏平均 macro）
accuracy = accuracy_score(true_labels, pred_labels)
precision_macro = precision_score(true_labels, pred_labels, average='macro')
recall_macro = recall_score(true_labels, pred_labels, average='macro')
f1_macro = f1_score(true_labels, pred_labels, average='macro')

# 可选：加权平均
precision_weighted = precision_score(true_labels, pred_labels, average='weighted')
recall_weighted = recall_score(true_labels, pred_labels, average='weighted')
f1_weighted = f1_score(true_labels, pred_labels, average='weighted')

# 5. 打印主要结果（宏平均）
print("评估结果（宏平均 Macro）：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}%")
print(f"精确率 (Precision): {precision_macro*100:.2f}%")
print(f"召回率 (Recall): {recall_macro*100:.2f}%")
print(f"F1 值 (F1-score): {f1_macro*100:.2f}%")

# 可选：打印加权平均
print("\n评估结果（加权平均 Weighted）：")
print(f"精确率 (Precision): {precision_weighted*100:.2f}%")
print(f"召回率 (Recall): {recall_weighted*100:.2f}%")
print(f"F1 值 (F1-score): {f1_weighted*100:.2f}%")

# 可选：打印每个类别的详细指标
print("\n各类别详细指标：")
print(classification_report(true_labels, pred_labels, digits=4))
# Out:
# 评估结果（宏平均 Macro）：
# 准确率 (Accuracy): 87.00%
# 精确率 (Precision): 74.25%
# 召回率 (Recall): 67.29%
# F1 值 (F1-score): 70.28%
#
# 评估结果（加权平均 Weighted）：
# 精确率 (Precision): 85.89%
# 召回率 (Recall): 87.00%
# F1 值 (F1-score): 86.25%
#
# 各类别详细指标：
#               precision    recall  f1-score   support
#
#            0     0.9118    0.9568    0.9337      1134
#            1     0.6042    0.4728    0.5305       184
#            2     0.6939    0.5312    0.6018        64
#            3     0.7600    0.7308    0.7451        26
#
#     accuracy                         0.8700      1408
#    macro avg     0.7425    0.6729    0.7028      1408
# weighted avg     0.8589    0.8700    0.8625      1408

# %%
import json, csv
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# ================== 配置区域 ==================
# 字体路径（请确保文件存在）
font_path = '/data/zhengtianlong/ttf/timesi.ttf'
# 测试集CSV文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
# 预测结果JSONL文件路径
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-35B-A3B-Base/lora/eval_2026-03-11-03-48-30_1/generated_predictions.jsonl"
# 输出图片保存路径
output_img_path = "/data/zhengtianlong/Private/Depressed/result_IMG/Qwen3.5-35B-A3B-Base_Multi_ROC_curves.png"
# =============================================

# 加载字体
times_new_roman_font = fm.FontProperties(fname=font_path)

def map_label(predict_str):
    """
    从预测字符串中提取类别标签（0-3）。
    假设模型输出中可能包含数字 '0','1','2','3'，按顺序匹配第一个数字。
    若未匹配到任何数字，默认返回3（可根据实际情况调整）。
    """
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认类别

# 1. 读取测试集真实标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target（0/1/2/3）
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性并截断
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 构建与画图代码兼容的数据格式（列表 of dict）
data = [{"label": t, "predict": p} for t, p in zip(true_labels, pred_labels)]

# 5. 准备ROC曲线所需数据
y_true = [int(item["label"]) for item in data]
y_pred = [int(item["predict"]) for item in data]  # 此处predict已是整数

# 将标签二值化
n_classes = 4
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])

# 类别名称映射（可根据实际修改）
class_names = {0: "non-depressed", 1: "mild", 2: "moderate", 3: "severe"}

# 计算ROC曲线和AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_pred_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类别的ROC曲线
plt.figure()
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             lw=2, label=f'{class_names[i]} (area = {roc_auc[i]:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontproperties=times_new_roman_font)
plt.ylabel('True Positive Rate', fontproperties=times_new_roman_font)
plt.title('Receiver Operating Characteristic (ROC) for each level', fontproperties=times_new_roman_font)
plt.legend(loc="lower right", prop=times_new_roman_font)

# 设置刻度字体
plt.xticks(fontproperties=times_new_roman_font)
plt.yticks(fontproperties=times_new_roman_font)

plt.savefig(output_img_path, format='png', dpi=800, bbox_inches='tight')
plt.show()

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-35B-A3B-Base/lora/eval_2026-03-11-03-48-30_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.2196
# Hamming Loss: 0.1981
#
# Macro Precision: 0.7511
# Macro Recall:    0.7172
# Macro F1-score:  0.7312
#
# Micro Precision: 0.7863
# Micro Recall:    0.7709
# Micro F1-score:  0.7785
#
# 每个类别的指标：
# anger:
#   Precision: 0.6915
#   Recall:    0.7275
#   F1-score:  0.7090
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.4741
#   Recall:    0.3216
#   F1-score:  0.3833
#   Support:   171
# emptiness:
#   Precision: 0.7912
#   Recall:    0.6891
#   F1-score:  0.7367
#   Support:   341
# hopelessness:
#   Precision: 0.8386
#   Recall:    0.8438
#   F1-score:  0.8412
#   Support:   634
# loneliness:
#   Precision: 0.8385
#   Recall:    0.7667
#   F1-score:  0.8010
#   Support:   420
# sadness:
#   Precision: 0.8473
#   Recall:    0.9154
#   F1-score:  0.8800
#   Support:   697
# suicide intent:
#   Precision: 0.8286
#   Recall:    0.7500
#   F1-score:  0.7873
#   Support:   232
# worthlessness:
#   Precision: 0.6993
#   Recall:    0.7235
# ...

# %% [markdown]
# ## Stage training (from 4 to 8)

# %% [markdown]
# ### Qwen3.5-0.8B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-0.8B-Base/lora/eval_2026-03-16-02-46-08_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：按顺序查找 '0','1','2','3'，返回第一个匹配的数字，若均未找到则默认返回3"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认返回3（可调整）

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算四分类指标（使用宏平均 macro）
accuracy = accuracy_score(true_labels, pred_labels)
precision_macro = precision_score(true_labels, pred_labels, average='macro')
recall_macro = recall_score(true_labels, pred_labels, average='macro')
f1_macro = f1_score(true_labels, pred_labels, average='macro')

# 可选：加权平均
precision_weighted = precision_score(true_labels, pred_labels, average='weighted')
recall_weighted = recall_score(true_labels, pred_labels, average='weighted')
f1_weighted = f1_score(true_labels, pred_labels, average='weighted')

# 5. 打印主要结果（宏平均）
print("评估结果（宏平均 Macro）：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}%")
print(f"精确率 (Precision): {precision_macro*100:.2f}%")
print(f"召回率 (Recall): {recall_macro*100:.2f}%")
print(f"F1 值 (F1-score): {f1_macro*100:.2f}%")

# 可选：打印加权平均
print("\n评估结果（加权平均 Weighted）：")
print(f"精确率 (Precision): {precision_weighted*100:.2f}%")
print(f"召回率 (Recall): {recall_weighted*100:.2f}%")
print(f"F1 值 (F1-score): {f1_weighted*100:.2f}%")

# 可选：打印每个类别的详细指标
print("\n各类别详细指标：")
print(classification_report(true_labels, pred_labels, digits=4))
# Out:
# 评估结果（宏平均 Macro）：
# 准确率 (Accuracy): 80.47%
# 精确率 (Precision): 54.53%
# 召回率 (Recall): 53.10%
# F1 值 (F1-score): 53.62%
#
# 评估结果（加权平均 Weighted）：
# 精确率 (Precision): 81.39%
# 召回率 (Recall): 80.47%
# F1 值 (F1-score): 80.89%
#
# 各类别详细指标：
#               precision    recall  f1-score   support
#
#            0     0.9173    0.8995    0.9083      1134
#            1     0.3883    0.4348    0.4103       184
#            2     0.3043    0.3281    0.3158        64
#            3     0.5714    0.4615    0.5106        26
#
#     accuracy                         0.8047      1408
#    macro avg     0.5453    0.5310    0.5362      1408
# weighted avg     0.8139    0.8047    0.8089      1408

# %%
import json, csv
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# ================== 配置区域 ==================
# 字体路径（请确保文件存在）
font_path = '/data/zhengtianlong/ttf/timesi.ttf'
# 测试集CSV文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
# 预测结果JSONL文件路径
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-0.8B-Base/lora/eval_2026-03-16-02-46-08_1/generated_predictions.jsonl"
# 输出图片保存路径
output_img_path = "/data/zhengtianlong/Private/Depressed/result_IMG/Qwen3.5-0.8B-Base_4to8_ROC_curves.png"
# =============================================

# 加载字体
times_new_roman_font = fm.FontProperties(fname=font_path)

def map_label(predict_str):
    """
    从预测字符串中提取类别标签（0-3）。
    假设模型输出中可能包含数字 '0','1','2','3'，按顺序匹配第一个数字。
    若未匹配到任何数字，默认返回3（可根据实际情况调整）。
    """
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认类别

# 1. 读取测试集真实标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target（0/1/2/3）
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性并截断
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 构建与画图代码兼容的数据格式（列表 of dict）
data = [{"label": t, "predict": p} for t, p in zip(true_labels, pred_labels)]

# 5. 准备ROC曲线所需数据
y_true = [int(item["label"]) for item in data]
y_pred = [int(item["predict"]) for item in data]  # 此处predict已是整数

# 将标签二值化
n_classes = 4
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])

# 类别名称映射（可根据实际修改）
class_names = {0: "non-depressed", 1: "mild", 2: "moderate", 3: "severe"}

# 计算ROC曲线和AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_pred_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类别的ROC曲线
plt.figure()
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             lw=2, label=f'{class_names[i]} (area = {roc_auc[i]:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontproperties=times_new_roman_font)
plt.ylabel('True Positive Rate', fontproperties=times_new_roman_font)
plt.title('Receiver Operating Characteristic (ROC) for each level', fontproperties=times_new_roman_font)
plt.legend(loc="lower right", prop=times_new_roman_font)

# 设置刻度字体
plt.xticks(fontproperties=times_new_roman_font)
plt.yticks(fontproperties=times_new_roman_font)

plt.savefig(output_img_path, format='png', dpi=800, bbox_inches='tight')
plt.show()

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-0.8B-Base/lora/eval_2026-03-16-02-46-08_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.1313
# Hamming Loss: 0.2562
#
# Macro Precision: 0.6510
# Macro Recall:    0.7003
# Macro F1-score:  0.6724
#
# Micro Precision: 0.6968
# Micro Recall:    0.7663
# Micro F1-score:  0.7299
#
# 每个类别的指标：
# anger:
#   Precision: 0.5521
#   Recall:    0.6754
#   F1-score:  0.6076
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.3359
#   Recall:    0.2573
#   F1-score:  0.2914
#   Support:   171
# emptiness:
#   Precision: 0.6371
#   Recall:    0.6950
#   F1-score:  0.6648
#   Support:   341
# hopelessness:
#   Precision: 0.7716
#   Recall:    0.8738
#   F1-score:  0.8195
#   Support:   634
# loneliness:
#   Precision: 0.7512
#   Recall:    0.7333
#   F1-score:  0.7422
#   Support:   420
# sadness:
#   Precision: 0.7952
#   Recall:    0.9412
#   F1-score:  0.8620
#   Support:   697
# suicide intent:
#   Precision: 0.7409
#   Recall:    0.7026
#   F1-score:  0.7212
#   Support:   232
# worthlessness:
#   Precision: 0.6243
#   Recall:    0.7235
# ...

# %% [markdown]
# ### Qwen3.5-2B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-2B-Base/lora/eval_2026-03-16-02-46-08_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：按顺序查找 '0','1','2','3'，返回第一个匹配的数字，若均未找到则默认返回3"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认返回3（可调整）

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算四分类指标（使用宏平均 macro）
accuracy = accuracy_score(true_labels, pred_labels)
precision_macro = precision_score(true_labels, pred_labels, average='macro')
recall_macro = recall_score(true_labels, pred_labels, average='macro')
f1_macro = f1_score(true_labels, pred_labels, average='macro')

# 可选：加权平均
precision_weighted = precision_score(true_labels, pred_labels, average='weighted')
recall_weighted = recall_score(true_labels, pred_labels, average='weighted')
f1_weighted = f1_score(true_labels, pred_labels, average='weighted')

# 5. 打印主要结果（宏平均）
print("评估结果（宏平均 Macro）：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}%")
print(f"精确率 (Precision): {precision_macro*100:.2f}%")
print(f"召回率 (Recall): {recall_macro*100:.2f}%")
print(f"F1 值 (F1-score): {f1_macro*100:.2f}%")

# 可选：打印加权平均
print("\n评估结果（加权平均 Weighted）：")
print(f"精确率 (Precision): {precision_weighted*100:.2f}%")
print(f"召回率 (Recall): {recall_weighted*100:.2f}%")
print(f"F1 值 (F1-score): {f1_weighted*100:.2f}%")

# 可选：打印每个类别的详细指标
print("\n各类别详细指标：")
print(classification_report(true_labels, pred_labels, digits=4))
# Out:
# 评估结果（宏平均 Macro）：
# 准确率 (Accuracy): 81.89%
# 精确率 (Precision): 57.41%
# 召回率 (Recall): 54.26%
# F1 值 (F1-score): 55.51%
#
# 评估结果（加权平均 Weighted）：
# 精确率 (Precision): 82.33%
# 召回率 (Recall): 81.89%
# F1 值 (F1-score): 82.04%
#
# 各类别详细指标：
#               precision    recall  f1-score   support
#
#            0     0.9206    0.9101    0.9153      1134
#            1     0.4233    0.4946    0.4561       184
#            2     0.3333    0.2656    0.2957        64
#            3     0.6190    0.5000    0.5532        26
#
#     accuracy                         0.8189      1408
#    macro avg     0.5741    0.5426    0.5551      1408
# weighted avg     0.8233    0.8189    0.8204      1408

# %%
import json, csv
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# ================== 配置区域 ==================
# 字体路径（请确保文件存在）
font_path = '/data/zhengtianlong/ttf/timesi.ttf'
# 测试集CSV文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
# 预测结果JSONL文件路径
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-2B-Base/lora/eval_2026-03-16-02-46-08_1/generated_predictions.jsonl"
# 输出图片保存路径
output_img_path = "/data/zhengtianlong/Private/Depressed/result_IMG/Qwen3.5-2B-Base_4to8_ROC_curves.png"
# =============================================

# 加载字体
times_new_roman_font = fm.FontProperties(fname=font_path)

def map_label(predict_str):
    """
    从预测字符串中提取类别标签（0-3）。
    假设模型输出中可能包含数字 '0','1','2','3'，按顺序匹配第一个数字。
    若未匹配到任何数字，默认返回3（可根据实际情况调整）。
    """
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认类别

# 1. 读取测试集真实标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target（0/1/2/3）
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性并截断
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 构建与画图代码兼容的数据格式（列表 of dict）
data = [{"label": t, "predict": p} for t, p in zip(true_labels, pred_labels)]

# 5. 准备ROC曲线所需数据
y_true = [int(item["label"]) for item in data]
y_pred = [int(item["predict"]) for item in data]  # 此处predict已是整数

# 将标签二值化
n_classes = 4
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])

# 类别名称映射（可根据实际修改）
class_names = {0: "non-depressed", 1: "mild", 2: "moderate", 3: "severe"}

# 计算ROC曲线和AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_pred_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类别的ROC曲线
plt.figure()
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             lw=2, label=f'{class_names[i]} (area = {roc_auc[i]:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontproperties=times_new_roman_font)
plt.ylabel('True Positive Rate', fontproperties=times_new_roman_font)
plt.title('Receiver Operating Characteristic (ROC) for each level', fontproperties=times_new_roman_font)
plt.legend(loc="lower right", prop=times_new_roman_font)

# 设置刻度字体
plt.xticks(fontproperties=times_new_roman_font)
plt.yticks(fontproperties=times_new_roman_font)

plt.savefig(output_img_path, format='png', dpi=800, bbox_inches='tight')
plt.show()

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-2B-Base/lora/eval_2026-03-16-02-46-08_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.1611
# Hamming Loss: 0.2312
#
# Macro Precision: 0.6904
# Macro Recall:    0.7196
# Macro F1-score:  0.7013
#
# Micro Precision: 0.7275
# Micro Recall:    0.7804
# Micro F1-score:  0.7530
#
# 每个类别的指标：
# anger:
#   Precision: 0.5704
#   Recall:    0.6928
#   F1-score:  0.6257
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.4132
#   Recall:    0.2924
#   F1-score:  0.3425
#   Support:   171
# emptiness:
#   Precision: 0.6841
#   Recall:    0.7302
#   F1-score:  0.7064
#   Support:   341
# hopelessness:
#   Precision: 0.7957
#   Recall:    0.8722
#   F1-score:  0.8322
#   Support:   634
# loneliness:
#   Precision: 0.7876
#   Recall:    0.7238
#   F1-score:  0.7543
#   Support:   420
# sadness:
#   Precision: 0.8066
#   Recall:    0.9512
#   F1-score:  0.8729
#   Support:   697
# suicide intent:
#   Precision: 0.8056
#   Recall:    0.7500
#   F1-score:  0.7768
#   Support:   232
# worthlessness:
#   Precision: 0.6605
#   Recall:    0.7442
# ...

# %% [markdown]
# ### Qwen3.5-4B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-4B-Base/lora/eval_2026-03-16-02-46-08_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：按顺序查找 '0','1','2','3'，返回第一个匹配的数字，若均未找到则默认返回3"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认返回3（可调整）

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算四分类指标（使用宏平均 macro）
accuracy = accuracy_score(true_labels, pred_labels)
precision_macro = precision_score(true_labels, pred_labels, average='macro')
recall_macro = recall_score(true_labels, pred_labels, average='macro')
f1_macro = f1_score(true_labels, pred_labels, average='macro')

# 可选：加权平均
precision_weighted = precision_score(true_labels, pred_labels, average='weighted')
recall_weighted = recall_score(true_labels, pred_labels, average='weighted')
f1_weighted = f1_score(true_labels, pred_labels, average='weighted')

# 5. 打印主要结果（宏平均）
print("评估结果（宏平均 Macro）：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}%")
print(f"精确率 (Precision): {precision_macro*100:.2f}%")
print(f"召回率 (Recall): {recall_macro*100:.2f}%")
print(f"F1 值 (F1-score): {f1_macro*100:.2f}%")

# 可选：打印加权平均
print("\n评估结果（加权平均 Weighted）：")
print(f"精确率 (Precision): {precision_weighted*100:.2f}%")
print(f"召回率 (Recall): {recall_weighted*100:.2f}%")
print(f"F1 值 (F1-score): {f1_weighted*100:.2f}%")

# 可选：打印每个类别的详细指标
print("\n各类别详细指标：")
print(classification_report(true_labels, pred_labels, digits=4))
# Out:
# 评估结果（宏平均 Macro）：
# 准确率 (Accuracy): 79.83%
# 精确率 (Precision): 55.81%
# 召回率 (Recall): 61.46%
# F1 值 (F1-score): 58.17%
#
# 评估结果（加权平均 Weighted）：
# 精确率 (Precision): 82.62%
# 召回率 (Recall): 79.83%
# F1 值 (F1-score): 81.05%
#
# 各类别详细指标：
#               precision    recall  f1-score   support
#
#            0     0.9334    0.8774    0.9045      1134
#            1     0.3773    0.4511    0.4109       184
#            2     0.3011    0.4375    0.3567        64
#            3     0.6207    0.6923    0.6545        26
#
#     accuracy                         0.7983      1408
#    macro avg     0.5581    0.6146    0.5817      1408
# weighted avg     0.8262    0.7983    0.8105      1408

# %%
import json, csv
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# ================== 配置区域 ==================
# 字体路径（请确保文件存在）
font_path = '/data/zhengtianlong/ttf/timesi.ttf'
# 测试集CSV文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
# 预测结果JSONL文件路径
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-4B-Base/lora/eval_2026-03-16-02-46-08_1/generated_predictions.jsonl"
# 输出图片保存路径
output_img_path = "/data/zhengtianlong/Private/Depressed/result_IMG/Qwen3.5-4B-Base_4to8_ROC_curves.png"
# =============================================

# 加载字体
times_new_roman_font = fm.FontProperties(fname=font_path)

def map_label(predict_str):
    """
    从预测字符串中提取类别标签（0-3）。
    假设模型输出中可能包含数字 '0','1','2','3'，按顺序匹配第一个数字。
    若未匹配到任何数字，默认返回3（可根据实际情况调整）。
    """
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认类别

# 1. 读取测试集真实标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target（0/1/2/3）
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性并截断
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 构建与画图代码兼容的数据格式（列表 of dict）
data = [{"label": t, "predict": p} for t, p in zip(true_labels, pred_labels)]

# 5. 准备ROC曲线所需数据
y_true = [int(item["label"]) for item in data]
y_pred = [int(item["predict"]) for item in data]  # 此处predict已是整数

# 将标签二值化
n_classes = 4
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])

# 类别名称映射（可根据实际修改）
class_names = {0: "non-depressed", 1: "mild", 2: "moderate", 3: "severe"}

# 计算ROC曲线和AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_pred_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类别的ROC曲线
plt.figure()
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             lw=2, label=f'{class_names[i]} (area = {roc_auc[i]:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontproperties=times_new_roman_font)
plt.ylabel('True Positive Rate', fontproperties=times_new_roman_font)
plt.title('Receiver Operating Characteristic (ROC) for each level', fontproperties=times_new_roman_font)
plt.legend(loc="lower right", prop=times_new_roman_font)

# 设置刻度字体
plt.xticks(fontproperties=times_new_roman_font)
plt.yticks(fontproperties=times_new_roman_font)

plt.savefig(output_img_path, format='png', dpi=800, bbox_inches='tight')
plt.show()

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-4B-Base/lora/eval_2026-03-16-02-46-08_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.1921
# Hamming Loss: 0.2141
#
# Macro Precision: 0.7123
# Macro Recall:    0.7456
# Macro F1-score:  0.7276
#
# Micro Precision: 0.7473
# Micro Recall:    0.7947
# Micro F1-score:  0.7703
#
# 每个类别的指标：
# anger:
#   Precision: 0.6434
#   Recall:    0.7478
#   F1-score:  0.6917
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.4161
#   Recall:    0.3918
#   F1-score:  0.4036
#   Support:   171
# emptiness:
#   Precision: 0.6825
#   Recall:    0.7185
#   F1-score:  0.7000
#   Support:   341
# hopelessness:
#   Precision: 0.8092
#   Recall:    0.8565
#   F1-score:  0.8322
#   Support:   634
# loneliness:
#   Precision: 0.8264
#   Recall:    0.8048
#   F1-score:  0.8154
#   Support:   420
# sadness:
#   Precision: 0.8256
#   Recall:    0.9440
#   F1-score:  0.8809
#   Support:   697
# suicide intent:
#   Precision: 0.8235
#   Recall:    0.7845
#   F1-score:  0.8035
#   Support:   232
# worthlessness:
#   Precision: 0.6717
#   Recall:    0.7166
# ...

# %% [markdown]
# ### Qwen3.5-9B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-9B-Base/lora/eval_2026-03-16-02-46-08_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：按顺序查找 '0','1','2','3'，返回第一个匹配的数字，若均未找到则默认返回3"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认返回3（可调整）

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算四分类指标（使用宏平均 macro）
accuracy = accuracy_score(true_labels, pred_labels)
precision_macro = precision_score(true_labels, pred_labels, average='macro')
recall_macro = recall_score(true_labels, pred_labels, average='macro')
f1_macro = f1_score(true_labels, pred_labels, average='macro')

# 可选：加权平均
precision_weighted = precision_score(true_labels, pred_labels, average='weighted')
recall_weighted = recall_score(true_labels, pred_labels, average='weighted')
f1_weighted = f1_score(true_labels, pred_labels, average='weighted')

# 5. 打印主要结果（宏平均）
print("评估结果（宏平均 Macro）：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}%")
print(f"精确率 (Precision): {precision_macro*100:.2f}%")
print(f"召回率 (Recall): {recall_macro*100:.2f}%")
print(f"F1 值 (F1-score): {f1_macro*100:.2f}%")

# 可选：打印加权平均
print("\n评估结果（加权平均 Weighted）：")
print(f"精确率 (Precision): {precision_weighted*100:.2f}%")
print(f"召回率 (Recall): {recall_weighted*100:.2f}%")
print(f"F1 值 (F1-score): {f1_weighted*100:.2f}%")

# 可选：打印每个类别的详细指标
print("\n各类别详细指标：")
print(classification_report(true_labels, pred_labels, digits=4))
# Out:
# 评估结果（宏平均 Macro）：
# 准确率 (Accuracy): 77.27%
# 精确率 (Precision): 54.31%
# 召回率 (Recall): 63.41%
# F1 值 (F1-score): 57.23%
#
# 评估结果（加权平均 Weighted）：
# 精确率 (Precision): 82.97%
# 召回率 (Recall): 77.27%
# F1 值 (F1-score): 79.55%
#
# 各类别详细指标：
#               precision    recall  f1-score   support
#
#            0     0.9465    0.8422    0.8913      1134
#            1     0.3333    0.4239    0.3732       184
#            2     0.2721    0.5781    0.3700        64
#            3     0.6207    0.6923    0.6545        26
#
#     accuracy                         0.7727      1408
#    macro avg     0.5431    0.6341    0.5723      1408
# weighted avg     0.8297    0.7727    0.7955      1408

# %%
import json, csv
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# ================== 配置区域 ==================
# 字体路径（请确保文件存在）
font_path = '/data/zhengtianlong/ttf/timesi.ttf'
# 测试集CSV文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
# 预测结果JSONL文件路径
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-9B-Base/lora/eval_2026-03-16-02-46-08_1/generated_predictions.jsonl"
# 输出图片保存路径
output_img_path = "/data/zhengtianlong/Private/Depressed/result_IMG/Qwen3.5-9B-Base_4to8_ROC_curves.png"
# =============================================

# 加载字体
times_new_roman_font = fm.FontProperties(fname=font_path)

def map_label(predict_str):
    """
    从预测字符串中提取类别标签（0-3）。
    假设模型输出中可能包含数字 '0','1','2','3'，按顺序匹配第一个数字。
    若未匹配到任何数字，默认返回3（可根据实际情况调整）。
    """
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认类别

# 1. 读取测试集真实标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target（0/1/2/3）
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性并截断
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 构建与画图代码兼容的数据格式（列表 of dict）
data = [{"label": t, "predict": p} for t, p in zip(true_labels, pred_labels)]

# 5. 准备ROC曲线所需数据
y_true = [int(item["label"]) for item in data]
y_pred = [int(item["predict"]) for item in data]  # 此处predict已是整数

# 将标签二值化
n_classes = 4
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])

# 类别名称映射（可根据实际修改）
class_names = {0: "non-depressed", 1: "mild", 2: "moderate", 3: "severe"}

# 计算ROC曲线和AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_pred_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类别的ROC曲线
plt.figure()
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             lw=2, label=f'{class_names[i]} (area = {roc_auc[i]:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontproperties=times_new_roman_font)
plt.ylabel('True Positive Rate', fontproperties=times_new_roman_font)
plt.title('Receiver Operating Characteristic (ROC) for each level', fontproperties=times_new_roman_font)
plt.legend(loc="lower right", prop=times_new_roman_font)

# 设置刻度字体
plt.xticks(fontproperties=times_new_roman_font)
plt.yticks(fontproperties=times_new_roman_font)

plt.savefig(output_img_path, format='png', dpi=800, bbox_inches='tight')
plt.show()

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-9B-Base/lora/eval_2026-03-16-02-46-08_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.2174
# Hamming Loss: 0.1981
#
# Macro Precision: 0.7265
# Macro Recall:    0.7512
# Macro F1-score:  0.7370
#
# Micro Precision: 0.7659
# Micro Recall:    0.8085
# Micro F1-score:  0.7866
#
# 每个类别的指标：
# anger:
#   Precision: 0.6572
#   Recall:    0.7391
#   F1-score:  0.6958
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.4265
#   Recall:    0.3392
#   F1-score:  0.3779
#   Support:   171
# emptiness:
#   Precision: 0.7273
#   Recall:    0.7507
#   F1-score:  0.7388
#   Support:   341
# hopelessness:
#   Precision: 0.8309
#   Recall:    0.8912
#   F1-score:  0.8600
#   Support:   634
# loneliness:
#   Precision: 0.7990
#   Recall:    0.7952
#   F1-score:  0.7971
#   Support:   420
# sadness:
#   Precision: 0.8333
#   Recall:    0.9469
#   F1-score:  0.8865
#   Support:   697
# suicide intent:
#   Precision: 0.8140
#   Recall:    0.7543
#   F1-score:  0.7830
#   Support:   232
# worthlessness:
#   Precision: 0.7242
#   Recall:    0.7926
# ...

# %% [markdown]
# ### Qwen3.5-35B-A3B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-35B-A3B-Base/lora/eval_2026-03-16-02-46-08_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：按顺序查找 '0','1','2','3'，返回第一个匹配的数字，若均未找到则默认返回3"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认返回3（可调整）

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算四分类指标（使用宏平均 macro）
accuracy = accuracy_score(true_labels, pred_labels)
precision_macro = precision_score(true_labels, pred_labels, average='macro')
recall_macro = recall_score(true_labels, pred_labels, average='macro')
f1_macro = f1_score(true_labels, pred_labels, average='macro')

# 可选：加权平均
precision_weighted = precision_score(true_labels, pred_labels, average='weighted')
recall_weighted = recall_score(true_labels, pred_labels, average='weighted')
f1_weighted = f1_score(true_labels, pred_labels, average='weighted')

# 5. 打印主要结果（宏平均）
print("评估结果（宏平均 Macro）：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}%")
print(f"精确率 (Precision): {precision_macro*100:.2f}%")
print(f"召回率 (Recall): {recall_macro*100:.2f}%")
print(f"F1 值 (F1-score): {f1_macro*100:.2f}%")

# 可选：打印加权平均
print("\n评估结果（加权平均 Weighted）：")
print(f"精确率 (Precision): {precision_weighted*100:.2f}%")
print(f"召回率 (Recall): {recall_weighted*100:.2f}%")
print(f"F1 值 (F1-score): {f1_weighted*100:.2f}%")

# 可选：打印每个类别的详细指标
print("\n各类别详细指标：")
print(classification_report(true_labels, pred_labels, digits=4))
# Out:
# 评估结果（宏平均 Macro）：
# 准确率 (Accuracy): 85.44%
# 精确率 (Precision): 68.19%
# 召回率 (Recall): 62.83%
# F1 值 (F1-score): 64.82%
#
# 评估结果（加权平均 Weighted）：
# 精确率 (Precision): 83.87%
# 召回率 (Recall): 85.44%
# F1 值 (F1-score): 84.24%
#
# 各类别详细指标：
#               precision    recall  f1-score   support
#
#            0     0.8974    0.9559    0.9257      1134
#            1     0.6034    0.3804    0.4667       184
#            2     0.5345    0.4844    0.5082        64
#            3     0.6923    0.6923    0.6923        26
#
#     accuracy                         0.8544      1408
#    macro avg     0.6819    0.6283    0.6482      1408
# weighted avg     0.8387    0.8544    0.8424      1408

# %%
import json, csv
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# ================== 配置区域 ==================
# 字体路径（请确保文件存在）
font_path = '/data/zhengtianlong/ttf/timesi.ttf'
# 测试集CSV文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
# 预测结果JSONL文件路径
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-35B-A3B-Base/lora/eval_2026-03-16-02-46-08_1/generated_predictions.jsonl"
# 输出图片保存路径
output_img_path = "/data/zhengtianlong/Private/Depressed/result_IMG/Qwen3.5-35B-A3B-Base_4to8_ROC_curves.png"
# =============================================

# 加载字体
times_new_roman_font = fm.FontProperties(fname=font_path)

def map_label(predict_str):
    """
    从预测字符串中提取类别标签（0-3）。
    假设模型输出中可能包含数字 '0','1','2','3'，按顺序匹配第一个数字。
    若未匹配到任何数字，默认返回3（可根据实际情况调整）。
    """
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认类别

# 1. 读取测试集真实标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target（0/1/2/3）
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性并截断
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 构建与画图代码兼容的数据格式（列表 of dict）
data = [{"label": t, "predict": p} for t, p in zip(true_labels, pred_labels)]

# 5. 准备ROC曲线所需数据
y_true = [int(item["label"]) for item in data]
y_pred = [int(item["predict"]) for item in data]  # 此处predict已是整数

# 将标签二值化
n_classes = 4
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])

# 类别名称映射（可根据实际修改）
class_names = {0: "non-depressed", 1: "mild", 2: "moderate", 3: "severe"}

# 计算ROC曲线和AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_pred_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类别的ROC曲线
plt.figure()
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             lw=2, label=f'{class_names[i]} (area = {roc_auc[i]:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontproperties=times_new_roman_font)
plt.ylabel('True Positive Rate', fontproperties=times_new_roman_font)
plt.title('Receiver Operating Characteristic (ROC) for each level', fontproperties=times_new_roman_font)
plt.legend(loc="lower right", prop=times_new_roman_font)

# 设置刻度字体
plt.xticks(fontproperties=times_new_roman_font)
plt.yticks(fontproperties=times_new_roman_font)

plt.savefig(output_img_path, format='png', dpi=800, bbox_inches='tight')
plt.show()

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-35B-A3B-Base/lora/eval_2026-03-16-02-46-08_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.1909
# Hamming Loss: 0.2093
#
# Macro Precision: 0.7317
# Macro Recall:    0.7251
# Macro F1-score:  0.7260
#
# Micro Precision: 0.7637
# Micro Recall:    0.7770
# Micro F1-score:  0.7703
#
# 每个类别的指标：
# anger:
#   Precision: 0.6702
#   Recall:    0.7420
#   F1-score:  0.7043
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.4651
#   Recall:    0.3509
#   F1-score:  0.4000
#   Support:   171
# emptiness:
#   Precision: 0.7508
#   Recall:    0.6716
#   F1-score:  0.7090
#   Support:   341
# hopelessness:
#   Precision: 0.8080
#   Recall:    0.8565
#   F1-score:  0.8315
#   Support:   634
# loneliness:
#   Precision: 0.8246
#   Recall:    0.7500
#   F1-score:  0.7855
#   Support:   420
# sadness:
#   Precision: 0.8310
#   Recall:    0.9383
#   F1-score:  0.8814
#   Support:   697
# suicide intent:
#   Precision: 0.8364
#   Recall:    0.7931
#   F1-score:  0.8142
#   Support:   232
# worthlessness:
#   Precision: 0.6674
#   Recall:    0.6982
# ...

# %% [markdown]
# ## Stage training (from 8 to 4)

# %% [markdown]
# ### Qwen3.5-0.8B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-0.8B-Base/lora/eval_2026-03-16-05-38-55_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：按顺序查找 '0','1','2','3'，返回第一个匹配的数字，若均未找到则默认返回3"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认返回3（可调整）

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算四分类指标（使用宏平均 macro）
accuracy = accuracy_score(true_labels, pred_labels)
precision_macro = precision_score(true_labels, pred_labels, average='macro')
recall_macro = recall_score(true_labels, pred_labels, average='macro')
f1_macro = f1_score(true_labels, pred_labels, average='macro')

# 可选：加权平均
precision_weighted = precision_score(true_labels, pred_labels, average='weighted')
recall_weighted = recall_score(true_labels, pred_labels, average='weighted')
f1_weighted = f1_score(true_labels, pred_labels, average='weighted')

# 5. 打印主要结果（宏平均）
print("评估结果（宏平均 Macro）：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}%")
print(f"精确率 (Precision): {precision_macro*100:.2f}%")
print(f"召回率 (Recall): {recall_macro*100:.2f}%")
print(f"F1 值 (F1-score): {f1_macro*100:.2f}%")

# 可选：打印加权平均
print("\n评估结果（加权平均 Weighted）：")
print(f"精确率 (Precision): {precision_weighted*100:.2f}%")
print(f"召回率 (Recall): {recall_weighted*100:.2f}%")
print(f"F1 值 (F1-score): {f1_weighted*100:.2f}%")

# 可选：打印每个类别的详细指标
print("\n各类别详细指标：")
print(classification_report(true_labels, pred_labels, digits=4))
# Out:
# 评估结果（宏平均 Macro）：
# 准确率 (Accuracy): 83.45%
# 精确率 (Precision): 60.97%
# 召回率 (Recall): 52.69%
# F1 值 (F1-score): 56.02%
#
# 评估结果（加权平均 Weighted）：
# 精确率 (Precision): 81.35%
# 召回率 (Recall): 83.45%
# F1 值 (F1-score): 82.16%
#
# 各类别详细指标：
#               precision    recall  f1-score   support
#
#            0     0.8960    0.9497    0.9221      1134
#            1     0.4658    0.3696    0.4121       184
#            2     0.4103    0.2500    0.3107        64
#            3     0.6667    0.5385    0.5957        26
#
#     accuracy                         0.8345      1408
#    macro avg     0.6097    0.5269    0.5602      1408
# weighted avg     0.8135    0.8345    0.8216      1408

# %%
import json, csv
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# ================== 配置区域 ==================
# 字体路径（请确保文件存在）
font_path = '/data/zhengtianlong/ttf/timesi.ttf'
# 测试集CSV文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
# 预测结果JSONL文件路径
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-0.8B-Base/lora/eval_2026-03-16-05-38-55_1/generated_predictions.jsonl"
# 输出图片保存路径
output_img_path = "/data/zhengtianlong/Private/Depressed/result_IMG/Qwen3.5-0.8B-Base_8to4_ROC_curves.png"
# =============================================

# 加载字体
times_new_roman_font = fm.FontProperties(fname=font_path)

def map_label(predict_str):
    """
    从预测字符串中提取类别标签（0-3）。
    假设模型输出中可能包含数字 '0','1','2','3'，按顺序匹配第一个数字。
    若未匹配到任何数字，默认返回3（可根据实际情况调整）。
    """
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认类别

# 1. 读取测试集真实标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target（0/1/2/3）
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性并截断
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 构建与画图代码兼容的数据格式（列表 of dict）
data = [{"label": t, "predict": p} for t, p in zip(true_labels, pred_labels)]

# 5. 准备ROC曲线所需数据
y_true = [int(item["label"]) for item in data]
y_pred = [int(item["predict"]) for item in data]  # 此处predict已是整数

# 将标签二值化
n_classes = 4
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])

# 类别名称映射（可根据实际修改）
class_names = {0: "non-depressed", 1: "mild", 2: "moderate", 3: "severe"}

# 计算ROC曲线和AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_pred_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类别的ROC曲线
plt.figure()
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             lw=2, label=f'{class_names[i]} (area = {roc_auc[i]:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontproperties=times_new_roman_font)
plt.ylabel('True Positive Rate', fontproperties=times_new_roman_font)
plt.title('Receiver Operating Characteristic (ROC) for each level', fontproperties=times_new_roman_font)
plt.legend(loc="lower right", prop=times_new_roman_font)

# 设置刻度字体
plt.xticks(fontproperties=times_new_roman_font)
plt.yticks(fontproperties=times_new_roman_font)

plt.savefig(output_img_path, format='png', dpi=800, bbox_inches='tight')
plt.show()

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-0.8B-Base/lora/eval_2026-03-16-05-38-55_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.0706
# Hamming Loss: 0.3402
#
# Macro Precision: 0.6857
# Macro Recall:    0.3814
# Macro F1-score:  0.4806
#
# Micro Precision: 0.7129
# Micro Recall:    0.4133
# Micro F1-score:  0.5232
#
# 每个类别的指标：
# anger:
#   Precision: 0.4772
#   Recall:    0.5159
#   F1-score:  0.4958
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.3333
#   Recall:    0.1111
#   F1-score:  0.1667
#   Support:   171
# emptiness:
#   Precision: 0.6894
#   Recall:    0.3255
#   F1-score:  0.4422
#   Support:   341
# hopelessness:
#   Precision: 0.7713
#   Recall:    0.5000
#   F1-score:  0.6067
#   Support:   634
# loneliness:
#   Precision: 0.8593
#   Recall:    0.4071
#   F1-score:  0.5525
#   Support:   420
# sadness:
#   Precision: 0.8575
#   Recall:    0.4663
#   F1-score:  0.6041
#   Support:   697
# suicide intent:
#   Precision: 0.8190
#   Recall:    0.4095
#   F1-score:  0.5460
#   Support:   232
# worthlessness:
#   Precision: 0.6782
#   Recall:    0.3157
# ...

# %% [markdown]
# ### Qwen3.5-2B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-2B-Base/lora/eval_2026-03-16-05-38-55_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：按顺序查找 '0','1','2','3'，返回第一个匹配的数字，若均未找到则默认返回3"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认返回3（可调整）

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算四分类指标（使用宏平均 macro）
accuracy = accuracy_score(true_labels, pred_labels)
precision_macro = precision_score(true_labels, pred_labels, average='macro')
recall_macro = recall_score(true_labels, pred_labels, average='macro')
f1_macro = f1_score(true_labels, pred_labels, average='macro')

# 可选：加权平均
precision_weighted = precision_score(true_labels, pred_labels, average='weighted')
recall_weighted = recall_score(true_labels, pred_labels, average='weighted')
f1_weighted = f1_score(true_labels, pred_labels, average='weighted')

# 5. 打印主要结果（宏平均）
print("评估结果（宏平均 Macro）：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}%")
print(f"精确率 (Precision): {precision_macro*100:.2f}%")
print(f"召回率 (Recall): {recall_macro*100:.2f}%")
print(f"F1 值 (F1-score): {f1_macro*100:.2f}%")

# 可选：打印加权平均
print("\n评估结果（加权平均 Weighted）：")
print(f"精确率 (Precision): {precision_weighted*100:.2f}%")
print(f"召回率 (Recall): {recall_weighted*100:.2f}%")
print(f"F1 值 (F1-score): {f1_weighted*100:.2f}%")

# 可选：打印每个类别的详细指标
print("\n各类别详细指标：")
print(classification_report(true_labels, pred_labels, digits=4))
# Out:
# 评估结果（宏平均 Macro）：
# 准确率 (Accuracy): 83.66%
# 精确率 (Precision): 56.18%
# 召回率 (Recall): 52.96%
# F1 值 (F1-score): 53.95%
#
# 评估结果（加权平均 Weighted）：
# 精确率 (Precision): 81.59%
# 召回率 (Recall): 83.66%
# F1 值 (F1-score): 82.43%
#
# 各类别详细指标：
#               precision    recall  f1-score   support
#
#            0     0.9054    0.9533    0.9287      1134
#            1     0.4658    0.3696    0.4121       184
#            2     0.3590    0.2188    0.2718        64
#            3     0.5172    0.5769    0.5455        26
#
#     accuracy                         0.8366      1408
#    macro avg     0.5618    0.5296    0.5395      1408
# weighted avg     0.8159    0.8366    0.8243      1408

# %%
import json, csv
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# ================== 配置区域 ==================
# 字体路径（请确保文件存在）
font_path = '/data/zhengtianlong/ttf/timesi.ttf'
# 测试集CSV文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
# 预测结果JSONL文件路径
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-2B-Base/lora/eval_2026-03-16-05-38-55_1/generated_predictions.jsonl"
# 输出图片保存路径
output_img_path = "/data/zhengtianlong/Private/Depressed/result_IMG/Qwen3.5-2B-Base_8to4_ROC_curves.png"
# =============================================

# 加载字体
times_new_roman_font = fm.FontProperties(fname=font_path)

def map_label(predict_str):
    """
    从预测字符串中提取类别标签（0-3）。
    假设模型输出中可能包含数字 '0','1','2','3'，按顺序匹配第一个数字。
    若未匹配到任何数字，默认返回3（可根据实际情况调整）。
    """
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认类别

# 1. 读取测试集真实标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target（0/1/2/3）
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性并截断
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 构建与画图代码兼容的数据格式（列表 of dict）
data = [{"label": t, "predict": p} for t, p in zip(true_labels, pred_labels)]

# 5. 准备ROC曲线所需数据
y_true = [int(item["label"]) for item in data]
y_pred = [int(item["predict"]) for item in data]  # 此处predict已是整数

# 将标签二值化
n_classes = 4
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])

# 类别名称映射（可根据实际修改）
class_names = {0: "non-depressed", 1: "mild", 2: "moderate", 3: "severe"}

# 计算ROC曲线和AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_pred_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类别的ROC曲线
plt.figure()
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             lw=2, label=f'{class_names[i]} (area = {roc_auc[i]:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontproperties=times_new_roman_font)
plt.ylabel('True Positive Rate', fontproperties=times_new_roman_font)
plt.title('Receiver Operating Characteristic (ROC) for each level', fontproperties=times_new_roman_font)
plt.legend(loc="lower right", prop=times_new_roman_font)

# 设置刻度字体
plt.xticks(fontproperties=times_new_roman_font)
plt.yticks(fontproperties=times_new_roman_font)

plt.savefig(output_img_path, format='png', dpi=800, bbox_inches='tight')
plt.show()

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-2B-Base/lora/eval_2026-03-16-05-38-55_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.0806
# Hamming Loss: 0.3219
#
# Macro Precision: 0.5783
# Macro Recall:    0.7433
# Macro F1-score:  0.6438
#
# Micro Precision: 0.6118
# Micro Recall:    0.7865
# Micro F1-score:  0.6882
#
# 每个类别的指标：
# anger:
#   Precision: 0.4102
#   Recall:    0.8609
#   F1-score:  0.5557
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.2310
#   Recall:    0.3743
#   F1-score:  0.2857
#   Support:   171
# emptiness:
#   Precision: 0.5603
#   Recall:    0.7361
#   F1-score:  0.6362
#   Support:   341
# hopelessness:
#   Precision: 0.7765
#   Recall:    0.8770
#   F1-score:  0.8237
#   Support:   634
# loneliness:
#   Precision: 0.6238
#   Recall:    0.7619
#   F1-score:  0.6860
#   Support:   420
# sadness:
#   Precision: 0.8116
#   Recall:    0.8838
#   F1-score:  0.8462
#   Support:   697
# suicide intent:
#   Precision: 0.5865
#   Recall:    0.7888
#   F1-score:  0.6728
#   Support:   232
# worthlessness:
#   Precision: 0.6261
#   Recall:    0.6636
# ...

# %% [markdown]
# ### Qwen3.5-4B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-4B-Base/lora/eval_2026-03-16-05-38-55_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：按顺序查找 '0','1','2','3'，返回第一个匹配的数字，若均未找到则默认返回3"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认返回3（可调整）

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算四分类指标（使用宏平均 macro）
accuracy = accuracy_score(true_labels, pred_labels)
precision_macro = precision_score(true_labels, pred_labels, average='macro')
recall_macro = recall_score(true_labels, pred_labels, average='macro')
f1_macro = f1_score(true_labels, pred_labels, average='macro')

# 可选：加权平均
precision_weighted = precision_score(true_labels, pred_labels, average='weighted')
recall_weighted = recall_score(true_labels, pred_labels, average='weighted')
f1_weighted = f1_score(true_labels, pred_labels, average='weighted')

# 5. 打印主要结果（宏平均）
print("评估结果（宏平均 Macro）：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}%")
print(f"精确率 (Precision): {precision_macro*100:.2f}%")
print(f"召回率 (Recall): {recall_macro*100:.2f}%")
print(f"F1 值 (F1-score): {f1_macro*100:.2f}%")

# 可选：打印加权平均
print("\n评估结果（加权平均 Weighted）：")
print(f"精确率 (Precision): {precision_weighted*100:.2f}%")
print(f"召回率 (Recall): {recall_weighted*100:.2f}%")
print(f"F1 值 (F1-score): {f1_weighted*100:.2f}%")

# 可选：打印每个类别的详细指标
print("\n各类别详细指标：")
print(classification_report(true_labels, pred_labels, digits=4))
# Out:
# 评估结果（宏平均 Macro）：
# 准确率 (Accuracy): 84.52%
# 精确率 (Precision): 63.31%
# 召回率 (Recall): 57.83%
# F1 值 (F1-score): 60.03%
#
# 评估结果（加权平均 Weighted）：
# 精确率 (Precision): 82.72%
# 召回率 (Recall): 84.52%
# F1 值 (F1-score): 83.44%
#
# 各类别详细指标：
#               precision    recall  f1-score   support
#
#            0     0.9076    0.9533    0.9299      1134
#            1     0.4901    0.4022    0.4418       184
#            2     0.4146    0.2656    0.3238        64
#            3     0.7200    0.6923    0.7059        26
#
#     accuracy                         0.8452      1408
#    macro avg     0.6331    0.5783    0.6003      1408
# weighted avg     0.8272    0.8452    0.8344      1408

# %%
import json, csv
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# ================== 配置区域 ==================
# 字体路径（请确保文件存在）
font_path = '/data/zhengtianlong/ttf/timesi.ttf'
# 测试集CSV文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
# 预测结果JSONL文件路径
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-4B-Base/lora/eval_2026-03-16-05-38-55_1/generated_predictions.jsonl"
# 输出图片保存路径
output_img_path = "/data/zhengtianlong/Private/Depressed/result_IMG/Qwen3.5-4B-Base_8to4_ROC_curves.png"
# =============================================

# 加载字体
times_new_roman_font = fm.FontProperties(fname=font_path)

def map_label(predict_str):
    """
    从预测字符串中提取类别标签（0-3）。
    假设模型输出中可能包含数字 '0','1','2','3'，按顺序匹配第一个数字。
    若未匹配到任何数字，默认返回3（可根据实际情况调整）。
    """
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认类别

# 1. 读取测试集真实标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target（0/1/2/3）
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性并截断
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 构建与画图代码兼容的数据格式（列表 of dict）
data = [{"label": t, "predict": p} for t, p in zip(true_labels, pred_labels)]

# 5. 准备ROC曲线所需数据
y_true = [int(item["label"]) for item in data]
y_pred = [int(item["predict"]) for item in data]  # 此处predict已是整数

# 将标签二值化
n_classes = 4
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])

# 类别名称映射（可根据实际修改）
class_names = {0: "non-depressed", 1: "mild", 2: "moderate", 3: "severe"}

# 计算ROC曲线和AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_pred_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类别的ROC曲线
plt.figure()
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             lw=2, label=f'{class_names[i]} (area = {roc_auc[i]:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontproperties=times_new_roman_font)
plt.ylabel('True Positive Rate', fontproperties=times_new_roman_font)
plt.title('Receiver Operating Characteristic (ROC) for each level', fontproperties=times_new_roman_font)
plt.legend(loc="lower right", prop=times_new_roman_font)

# 设置刻度字体
plt.xticks(fontproperties=times_new_roman_font)
plt.yticks(fontproperties=times_new_roman_font)

plt.savefig(output_img_path, format='png', dpi=800, bbox_inches='tight')
plt.show()

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-4B-Base/lora/eval_2026-03-16-05-38-55_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.1170
# Hamming Loss: 0.2648
#
# Macro Precision: 0.7316
# Macro Recall:    0.5639
# Macro F1-score:  0.6214
#
# Micro Precision: 0.7579
# Micro Recall:    0.6081
# Micro F1-score:  0.6748
#
# 每个类别的指标：
# anger:
#   Precision: 0.5140
#   Recall:    0.6928
#   F1-score:  0.5901
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.4815
#   Recall:    0.1520
#   F1-score:  0.2311
#   Support:   171
# emptiness:
#   Precision: 0.6644
#   Recall:    0.5806
#   F1-score:  0.6197
#   Support:   341
# hopelessness:
#   Precision: 0.8407
#   Recall:    0.6325
#   F1-score:  0.7219
#   Support:   634
# loneliness:
#   Precision: 0.8548
#   Recall:    0.6167
#   F1-score:  0.7165
#   Support:   420
# sadness:
#   Precision: 0.8615
#   Recall:    0.7762
#   F1-score:  0.8166
#   Support:   697
# suicide intent:
#   Precision: 0.8596
#   Recall:    0.6595
#   F1-score:  0.7463
#   Support:   232
# worthlessness:
#   Precision: 0.7768
#   Recall:    0.4009
# ...

# %% [markdown]
# ### Qwen3.5-9B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-9B-Base/lora/eval_2026-03-16-05-38-55_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：按顺序查找 '0','1','2','3'，返回第一个匹配的数字，若均未找到则默认返回3"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认返回3（可调整）

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算四分类指标（使用宏平均 macro）
accuracy = accuracy_score(true_labels, pred_labels)
precision_macro = precision_score(true_labels, pred_labels, average='macro')
recall_macro = recall_score(true_labels, pred_labels, average='macro')
f1_macro = f1_score(true_labels, pred_labels, average='macro')

# 可选：加权平均
precision_weighted = precision_score(true_labels, pred_labels, average='weighted')
recall_weighted = recall_score(true_labels, pred_labels, average='weighted')
f1_weighted = f1_score(true_labels, pred_labels, average='weighted')

# 5. 打印主要结果（宏平均）
print("评估结果（宏平均 Macro）：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}%")
print(f"精确率 (Precision): {precision_macro*100:.2f}%")
print(f"召回率 (Recall): {recall_macro*100:.2f}%")
print(f"F1 值 (F1-score): {f1_macro*100:.2f}%")

# 可选：打印加权平均
print("\n评估结果（加权平均 Weighted）：")
print(f"精确率 (Precision): {precision_weighted*100:.2f}%")
print(f"召回率 (Recall): {recall_weighted*100:.2f}%")
print(f"F1 值 (F1-score): {f1_weighted*100:.2f}%")

# 可选：打印每个类别的详细指标
print("\n各类别详细指标：")
print(classification_report(true_labels, pred_labels, digits=4))
# Out:
# 评估结果（宏平均 Macro）：
# 准确率 (Accuracy): 85.09%
# 精确率 (Precision): 65.26%
# 召回率 (Recall): 58.49%
# F1 值 (F1-score): 61.23%
#
# 评估结果（加权平均 Weighted）：
# 精确率 (Precision): 83.29%
# 召回率 (Recall): 85.09%
# F1 值 (F1-score): 83.98%
#
# 各类别详细指标：
#               precision    recall  f1-score   support
#
#            0     0.9104    0.9586    0.9338      1134
#            1     0.5000    0.4076    0.4491       184
#            2     0.4500    0.2812    0.3462        64
#            3     0.7500    0.6923    0.7200        26
#
#     accuracy                         0.8509      1408
#    macro avg     0.6526    0.5849    0.6123      1408
# weighted avg     0.8329    0.8509    0.8398      1408

# %%
import json, csv
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# ================== 配置区域 ==================
# 字体路径（请确保文件存在）
font_path = '/data/zhengtianlong/ttf/timesi.ttf'
# 测试集CSV文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
# 预测结果JSONL文件路径
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-9B-Base/lora/eval_2026-03-16-05-38-55_1/generated_predictions.jsonl"
# 输出图片保存路径
output_img_path = "/data/zhengtianlong/Private/Depressed/result_IMG/Qwen3.5-9B-Base_8to4_ROC_curves.png"
# =============================================

# 加载字体
times_new_roman_font = fm.FontProperties(fname=font_path)

def map_label(predict_str):
    """
    从预测字符串中提取类别标签（0-3）。
    假设模型输出中可能包含数字 '0','1','2','3'，按顺序匹配第一个数字。
    若未匹配到任何数字，默认返回3（可根据实际情况调整）。
    """
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认类别

# 1. 读取测试集真实标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target（0/1/2/3）
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性并截断
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 构建与画图代码兼容的数据格式（列表 of dict）
data = [{"label": t, "predict": p} for t, p in zip(true_labels, pred_labels)]

# 5. 准备ROC曲线所需数据
y_true = [int(item["label"]) for item in data]
y_pred = [int(item["predict"]) for item in data]  # 此处predict已是整数

# 将标签二值化
n_classes = 4
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])

# 类别名称映射（可根据实际修改）
class_names = {0: "non-depressed", 1: "mild", 2: "moderate", 3: "severe"}

# 计算ROC曲线和AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_pred_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类别的ROC曲线
plt.figure()
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             lw=2, label=f'{class_names[i]} (area = {roc_auc[i]:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontproperties=times_new_roman_font)
plt.ylabel('True Positive Rate', fontproperties=times_new_roman_font)
plt.title('Receiver Operating Characteristic (ROC) for each level', fontproperties=times_new_roman_font)
plt.legend(loc="lower right", prop=times_new_roman_font)

# 设置刻度字体
plt.xticks(fontproperties=times_new_roman_font)
plt.yticks(fontproperties=times_new_roman_font)

plt.savefig(output_img_path, format='png', dpi=800, bbox_inches='tight')
plt.show()

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-9B-Base/lora/eval_2026-03-16-05-38-55_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.1578
# Hamming Loss: 0.2532
#
# Macro Precision: 0.7175
# Macro Recall:    0.5905
# Macro F1-score:  0.6351
#
# Micro Precision: 0.7560
# Micro Recall:    0.6491
# Micro F1-score:  0.6984
#
# 每个类别的指标：
# anger:
#   Precision: 0.5899
#   Recall:    0.6087
#   F1-score:  0.5991
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.4583
#   Recall:    0.1287
#   F1-score:  0.2009
#   Support:   171
# emptiness:
#   Precision: 0.6483
#   Recall:    0.6540
#   F1-score:  0.6511
#   Support:   341
# hopelessness:
#   Precision: 0.8290
#   Recall:    0.7114
#   F1-score:  0.7657
#   Support:   634
# loneliness:
#   Precision: 0.7610
#   Recall:    0.7429
#   F1-score:  0.7518
#   Support:   420
# sadness:
#   Precision: 0.8502
#   Recall:    0.8063
#   F1-score:  0.8277
#   Support:   697
# suicide intent:
#   Precision: 0.9020
#   Recall:    0.5948
#   F1-score:  0.7169
#   Support:   232
# worthlessness:
#   Precision: 0.7017
#   Recall:    0.4770
# ...

# %% [markdown]
# ### Qwen3.5-35B-A3B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-35B-A3B-Base/lora/eval_2026-03-16-05-38-55_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：按顺序查找 '0','1','2','3'，返回第一个匹配的数字，若均未找到则默认返回3"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认返回3（可调整）

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算四分类指标（使用宏平均 macro）
accuracy = accuracy_score(true_labels, pred_labels)
precision_macro = precision_score(true_labels, pred_labels, average='macro')
recall_macro = recall_score(true_labels, pred_labels, average='macro')
f1_macro = f1_score(true_labels, pred_labels, average='macro')

# 可选：加权平均
precision_weighted = precision_score(true_labels, pred_labels, average='weighted')
recall_weighted = recall_score(true_labels, pred_labels, average='weighted')
f1_weighted = f1_score(true_labels, pred_labels, average='weighted')

# 5. 打印主要结果（宏平均）
print("评估结果（宏平均 Macro）：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}%")
print(f"精确率 (Precision): {precision_macro*100:.2f}%")
print(f"召回率 (Recall): {recall_macro*100:.2f}%")
print(f"F1 值 (F1-score): {f1_macro*100:.2f}%")

# 可选：打印加权平均
print("\n评估结果（加权平均 Weighted）：")
print(f"精确率 (Precision): {precision_weighted*100:.2f}%")
print(f"召回率 (Recall): {recall_weighted*100:.2f}%")
print(f"F1 值 (F1-score): {f1_weighted*100:.2f}%")

# 可选：打印每个类别的详细指标
print("\n各类别详细指标：")
print(classification_report(true_labels, pred_labels, digits=4))
# Out:
# 评估结果（宏平均 Macro）：
# 准确率 (Accuracy): 86.79%
# 精确率 (Precision): 71.93%
# 召回率 (Recall): 66.26%
# F1 值 (F1-score): 68.65%
#
# 评估结果（加权平均 Weighted）：
# 精确率 (Precision): 85.58%
# 召回率 (Recall): 86.79%
# F1 值 (F1-score): 85.98%
#
# 各类别详细指标：
#               precision    recall  f1-score   support
#
#            0     0.9118    0.9577    0.9342      1134
#            1     0.6071    0.4620    0.5247       184
#            2     0.6275    0.5000    0.5565        64
#            3     0.7308    0.7308    0.7308        26
#
#     accuracy                         0.8679      1408
#    macro avg     0.7193    0.6626    0.6865      1408
# weighted avg     0.8558    0.8679    0.8598      1408

# %%
import json, csv
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# ================== 配置区域 ==================
# 字体路径（请确保文件存在）
font_path = '/data/zhengtianlong/ttf/timesi.ttf'
# 测试集CSV文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test.csv"
# 预测结果JSONL文件路径
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-35B-A3B-Base/lora/eval_2026-03-16-05-38-55_1/generated_predictions.jsonl"
# 输出图片保存路径
output_img_path = "/data/zhengtianlong/Private/Depressed/result_IMG/Qwen3.5-35B-A3B-Base_8to4_ROC_curves.png"
# =============================================

# 加载字体
times_new_roman_font = fm.FontProperties(fname=font_path)

def map_label(predict_str):
    """
    从预测字符串中提取类别标签（0-3）。
    假设模型输出中可能包含数字 '0','1','2','3'，按顺序匹配第一个数字。
    若未匹配到任何数字，默认返回3（可根据实际情况调整）。
    """
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    elif "2" in predict_str:
        return 2
    elif "3" in predict_str:
        return 3
    else:
        return 3  # 默认类别

# 1. 读取测试集真实标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target（0/1/2/3）
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性并截断
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 构建与画图代码兼容的数据格式（列表 of dict）
data = [{"label": t, "predict": p} for t, p in zip(true_labels, pred_labels)]

# 5. 准备ROC曲线所需数据
y_true = [int(item["label"]) for item in data]
y_pred = [int(item["predict"]) for item in data]  # 此处predict已是整数

# 将标签二值化
n_classes = 4
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])

# 类别名称映射（可根据实际修改）
class_names = {0: "non-depressed", 1: "mild", 2: "moderate", 3: "severe"}

# 计算ROC曲线和AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_pred_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类别的ROC曲线
plt.figure()
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             lw=2, label=f'{class_names[i]} (area = {roc_auc[i]:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontproperties=times_new_roman_font)
plt.ylabel('True Positive Rate', fontproperties=times_new_roman_font)
plt.title('Receiver Operating Characteristic (ROC) for each level', fontproperties=times_new_roman_font)
plt.legend(loc="lower right", prop=times_new_roman_font)

# 设置刻度字体
plt.xticks(fontproperties=times_new_roman_font)
plt.yticks(fontproperties=times_new_roman_font)

plt.savefig(output_img_path, format='png', dpi=800, bbox_inches='tight')
plt.show()

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-35B-A3B-Base/lora/eval_2026-03-16-05-38-55_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.1313
# Hamming Loss: 0.2692
#
# Macro Precision: 0.7352
# Macro Recall:    0.5231
# Macro F1-score:  0.6055
#
# Micro Precision: 0.7767
# Micro Recall:    0.5672
# Micro F1-score:  0.6556
#
# 每个类别的指标：
# anger:
#   Precision: 0.6047
#   Recall:    0.5188
#   F1-score:  0.5585
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.3520
#   Recall:    0.2573
#   F1-score:  0.2973
#   Support:   171
# emptiness:
#   Precision: 0.7514
#   Recall:    0.3900
#   F1-score:  0.5135
#   Support:   341
# hopelessness:
#   Precision: 0.8683
#   Recall:    0.5615
#   F1-score:  0.6820
#   Support:   634
# loneliness:
#   Precision: 0.8794
#   Recall:    0.5905
#   F1-score:  0.7066
#   Support:   420
# sadness:
#   Precision: 0.8326
#   Recall:    0.8135
#   F1-score:  0.8229
#   Support:   697
# suicide intent:
#   Precision: 0.8538
#   Recall:    0.6293
#   F1-score:  0.7246
#   Support:   232
# worthlessness:
#   Precision: 0.7390
#   Recall:    0.4240
# ...

# %% [markdown]
# ## Stage training (from 2 to 8)

# %% [markdown]
# ### Qwen3.5-0.8B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test_binary.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-0.8B-Base/lora/eval_2026-03-17-02-40-34_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：如果包含 '0' 返回0，否则如果包含 '1' 返回1，否则默认返回1"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    else:
        return 1  # 默认返回1

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        # target 可能为字符串 '0' 或 '1'，转为整数
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算指标
accuracy = accuracy_score(true_labels, pred_labels)
precision = precision_score(true_labels, pred_labels, pos_label=1) # pos_label=1 指定正类为抑郁（1）
recall = recall_score(true_labels, pred_labels, pos_label=1)
f1 = f1_score(true_labels, pred_labels, pos_label=1)

# 5. 打印结果
print("评估结果：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}")
print(f"精确率 (Precision): {precision*100:.2f}")
print(f"召回率 (Recall): {recall*100:.2f}")
print(f"F1 值 (F1-score): {f1*100:.2f}")
# Out:
# 评估结果：
# 准确率 (Accuracy): 86.72
# 精确率 (Precision): 68.20
# 召回率 (Recall): 59.49
# F1 值 (F1-score): 63.55

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-0.8B-Base/lora/eval_2026-03-17-02-40-34_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.1380
# Hamming Loss: 0.2493
#
# Macro Precision: 0.6563
# Macro Recall:    0.7016
# Macro F1-score:  0.6762
#
# Micro Precision: 0.7069
# Micro Recall:    0.7654
# Micro F1-score:  0.7350
#
# 每个类别的指标：
# anger:
#   Precision: 0.5691
#   Recall:    0.7159
#   F1-score:  0.6341
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.2920
#   Recall:    0.2339
#   F1-score:  0.2597
#   Support:   171
# emptiness:
#   Precision: 0.6513
#   Recall:    0.6628
#   F1-score:  0.6570
#   Support:   341
# hopelessness:
#   Precision: 0.8038
#   Recall:    0.8659
#   F1-score:  0.8337
#   Support:   634
# loneliness:
#   Precision: 0.7716
#   Recall:    0.7238
#   F1-score:  0.7469
#   Support:   420
# sadness:
#   Precision: 0.7941
#   Recall:    0.9297
#   F1-score:  0.8566
#   Support:   697
# suicide intent:
#   Precision: 0.7238
#   Recall:    0.7457
#   F1-score:  0.7346
#   Support:   232
# worthlessness:
#   Precision: 0.6444
#   Recall:    0.7350
# ...

# %% [markdown]
# ### Qwen3.5-2B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test_binary.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-2B-Base/lora/eval_2026-03-17-02-40-34_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：如果包含 '0' 返回0，否则如果包含 '1' 返回1，否则默认返回1"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    else:
        return 1  # 默认返回1

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        # target 可能为字符串 '0' 或 '1'，转为整数
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算指标
accuracy = accuracy_score(true_labels, pred_labels)
precision = precision_score(true_labels, pred_labels, pos_label=1) # pos_label=1 指定正类为抑郁（1）
recall = recall_score(true_labels, pred_labels, pos_label=1)
f1 = f1_score(true_labels, pred_labels, pos_label=1)

# 5. 打印结果
print("评估结果：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}")
print(f"精确率 (Precision): {precision*100:.2f}")
print(f"召回率 (Recall): {recall*100:.2f}")
print(f"F1 值 (F1-score): {f1*100:.2f}")
# Out:
# 评估结果：
# 准确率 (Accuracy): 86.93
# 精确率 (Precision): 67.44
# 召回率 (Recall): 63.50
# F1 值 (F1-score): 65.41

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-2B-Base/lora/eval_2026-03-17-02-40-34_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.1578
# Hamming Loss: 0.2329
#
# Macro Precision: 0.6808
# Macro Recall:    0.7203
# Macro F1-score:  0.6973
#
# Micro Precision: 0.7239
# Micro Recall:    0.7831
# Micro F1-score:  0.7523
#
# 每个类别的指标：
# anger:
#   Precision: 0.5731
#   Recall:    0.7275
#   F1-score:  0.6411
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.3615
#   Recall:    0.2749
#   F1-score:  0.3123
#   Support:   171
# emptiness:
#   Precision: 0.6872
#   Recall:    0.7214
#   F1-score:  0.7039
#   Support:   341
# hopelessness:
#   Precision: 0.7954
#   Recall:    0.8770
#   F1-score:  0.8342
#   Support:   634
# loneliness:
#   Precision: 0.7995
#   Recall:    0.7500
#   F1-score:  0.7740
#   Support:   420
# sadness:
#   Precision: 0.8086
#   Recall:    0.9455
#   F1-score:  0.8717
#   Support:   697
# suicide intent:
#   Precision: 0.7602
#   Recall:    0.7241
#   F1-score:  0.7417
#   Support:   232
# worthlessness:
#   Precision: 0.6612
#   Recall:    0.7419
# ...

# %% [markdown]
# ### Qwen3.5-4B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test_binary.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-4B-Base/lora/eval_2026-03-17-02-40-34_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：如果包含 '0' 返回0，否则如果包含 '1' 返回1，否则默认返回1"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    else:
        return 1  # 默认返回1

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        # target 可能为字符串 '0' 或 '1'，转为整数
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算指标
accuracy = accuracy_score(true_labels, pred_labels)
precision = precision_score(true_labels, pred_labels, pos_label=1) # pos_label=1 指定正类为抑郁（1）
recall = recall_score(true_labels, pred_labels, pos_label=1)
f1 = f1_score(true_labels, pred_labels, pos_label=1)

# 5. 打印结果
print("评估结果：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}")
print(f"精确率 (Precision): {precision*100:.2f}")
print(f"召回率 (Recall): {recall*100:.2f}")
print(f"F1 值 (F1-score): {f1*100:.2f}")
# Out:
# 评估结果：
# 准确率 (Accuracy): 85.94
# 精确率 (Precision): 61.31
# 召回率 (Recall): 75.18
# F1 值 (F1-score): 67.54

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-4B-Base/lora/eval_2026-03-17-02-40-34_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.1898
# Hamming Loss: 0.2140
#
# Macro Precision: 0.7078
# Macro Recall:    0.7363
# Macro F1-score:  0.7205
#
# Micro Precision: 0.7491
# Micro Recall:    0.7914
# Micro F1-score:  0.7696
#
# 每个类别的指标：
# anger:
#   Precision: 0.6359
#   Recall:    0.7594
#   F1-score:  0.6922
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.3506
#   Recall:    0.3158
#   F1-score:  0.3323
#   Support:   171
# emptiness:
#   Precision: 0.7164
#   Recall:    0.7185
#   F1-score:  0.7174
#   Support:   341
# hopelessness:
#   Precision: 0.8088
#   Recall:    0.8675
#   F1-score:  0.8371
#   Support:   634
# loneliness:
#   Precision: 0.8278
#   Recall:    0.7786
#   F1-score:  0.8025
#   Support:   420
# sadness:
#   Precision: 0.8208
#   Recall:    0.9397
#   F1-score:  0.8763
#   Support:   697
# suicide intent:
#   Precision: 0.8009
#   Recall:    0.7802
#   F1-score:  0.7904
#   Support:   232
# worthlessness:
#   Precision: 0.7013
#   Recall:    0.7304
# ...

# %% [markdown]
# ### Qwen3.5-9B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test_binary.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-9B-Base/lora/eval_2026-03-17-02-40-34_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：如果包含 '0' 返回0，否则如果包含 '1' 返回1，否则默认返回1"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    else:
        return 1  # 默认返回1

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        # target 可能为字符串 '0' 或 '1'，转为整数
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算指标
accuracy = accuracy_score(true_labels, pred_labels)
precision = precision_score(true_labels, pred_labels, pos_label=1) # pos_label=1 指定正类为抑郁（1）
recall = recall_score(true_labels, pred_labels, pos_label=1)
f1 = f1_score(true_labels, pred_labels, pos_label=1)

# 5. 打印结果
print("评估结果：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}")
print(f"精确率 (Precision): {precision*100:.2f}")
print(f"召回率 (Recall): {recall*100:.2f}")
print(f"F1 值 (F1-score): {f1*100:.2f}")
# Out:
# 评估结果：
# 准确率 (Accuracy): 85.30
# 精确率 (Precision): 59.03
# 召回率 (Recall): 79.93
# F1 值 (F1-score): 67.91

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-9B-Base/lora/eval_2026-03-17-02-40-34_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.1943
# Hamming Loss: 0.2086
#
# Macro Precision: 0.7157
# Macro Recall:    0.7422
# Macro F1-score:  0.7275
#
# Micro Precision: 0.7557
# Micro Recall:    0.7954
# Micro F1-score:  0.7750
#
# 每个类别的指标：
# anger:
#   Precision: 0.6450
#   Recall:    0.7478
#   F1-score:  0.6926
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.3931
#   Recall:    0.3333
#   F1-score:  0.3608
#   Support:   171
# emptiness:
#   Precision: 0.7275
#   Recall:    0.7595
#   F1-score:  0.7432
#   Support:   341
# hopelessness:
#   Precision: 0.8223
#   Recall:    0.8612
#   F1-score:  0.8413
#   Support:   634
# loneliness:
#   Precision: 0.8093
#   Recall:    0.7881
#   F1-score:  0.7986
#   Support:   420
# sadness:
#   Precision: 0.8304
#   Recall:    0.9412
#   F1-score:  0.8823
#   Support:   697
# suicide intent:
#   Precision: 0.8072
#   Recall:    0.7759
#   F1-score:  0.7912
#   Support:   232
# worthlessness:
#   Precision: 0.6906
#   Recall:    0.7304
# ...

# %% [markdown]
# ### Qwen3.5-35B-A3B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test_binary.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-35B-A3B-Base/lora/eval_2026-03-17-02-40-34_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：如果包含 '0' 返回0，否则如果包含 '1' 返回1，否则默认返回1"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    else:
        return 1  # 默认返回1

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        # target 可能为字符串 '0' 或 '1'，转为整数
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算指标
accuracy = accuracy_score(true_labels, pred_labels)
precision = precision_score(true_labels, pred_labels, pos_label=1)
recall = recall_score(true_labels, pred_labels, pos_label=1)
f1 = f1_score(true_labels, pred_labels, pos_label=1)

# 5. 打印结果
print("评估结果：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}")
print(f"精确率 (Precision): {precision*100:.2f}")
print(f"召回率 (Recall): {recall*100:.2f}")
print(f"F1 值 (F1-score): {f1*100:.2f}")
# Out:
# 评估结果：
# 准确率 (Accuracy): 88.42
# 精确率 (Precision): 75.58
# 召回率 (Recall): 59.85
# F1 值 (F1-score): 66.80

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-35B-A3B-Base/lora/eval_2026-03-17-02-40-34_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.1932
# Hamming Loss: 0.2144
#
# Macro Precision: 0.7174
# Macro Recall:    0.7223
# Macro F1-score:  0.7158
#
# Micro Precision: 0.7531
# Micro Recall:    0.7816
# Micro F1-score:  0.7671
#
# 每个类别的指标：
# anger:
#   Precision: 0.6463
#   Recall:    0.7362
#   F1-score:  0.6883
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.4808
#   Recall:    0.2924
#   F1-score:  0.3636
#   Support:   171
# emptiness:
#   Precision: 0.6867
#   Recall:    0.6686
#   F1-score:  0.6776
#   Support:   341
# hopelessness:
#   Precision: 0.8209
#   Recall:    0.8817
#   F1-score:  0.8502
#   Support:   634
# loneliness:
#   Precision: 0.7946
#   Recall:    0.7738
#   F1-score:  0.7841
#   Support:   420
# sadness:
#   Precision: 0.8222
#   Recall:    0.9354
#   F1-score:  0.8752
#   Support:   697
# suicide intent:
#   Precision: 0.8211
#   Recall:    0.7716
#   F1-score:  0.7956
#   Support:   232
# worthlessness:
#   Precision: 0.6667
#   Recall:    0.7189
# ...

# %% [markdown]
# ## Stage training (from 8 to 2)

# %% [markdown]
# ### Qwen3.5-0.8B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test_binary.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-0.8B-Base/lora/eval_2026-03-17-05-15-18_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：如果包含 '0' 返回0，否则如果包含 '1' 返回1，否则默认返回1"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    else:
        return 1  # 默认返回1

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        # target 可能为字符串 '0' 或 '1'，转为整数
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算指标
accuracy = accuracy_score(true_labels, pred_labels)
precision = precision_score(true_labels, pred_labels, pos_label=1) # pos_label=1 指定正类为抑郁（1）
recall = recall_score(true_labels, pred_labels, pos_label=1)
f1 = f1_score(true_labels, pred_labels, pos_label=1)

# 5. 打印结果
print("评估结果：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}")
print(f"精确率 (Precision): {precision*100:.2f}")
print(f"召回率 (Recall): {recall*100:.2f}")
print(f"F1 值 (F1-score): {f1*100:.2f}")
# Out:
# 评估结果：
# 准确率 (Accuracy): 87.93
# 精确率 (Precision): 73.01
# 召回率 (Recall): 60.22
# F1 值 (F1-score): 66.00

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-0.8B-Base/lora/eval_2026-03-17-05-15-18_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.0861
# Hamming Loss: 0.3122
#
# Macro Precision: 0.6712
# Macro Recall:    0.4619
# Macro F1-score:  0.5391
#
# Micro Precision: 0.7178
# Micro Recall:    0.5089
# Micro F1-score:  0.5955
#
# 每个类别的指标：
# anger:
#   Precision: 0.4926
#   Recall:    0.5826
#   F1-score:  0.5339
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.3378
#   Recall:    0.1462
#   F1-score:  0.2041
#   Support:   171
# emptiness:
#   Precision: 0.6619
#   Recall:    0.4076
#   F1-score:  0.5045
#   Support:   341
# hopelessness:
#   Precision: 0.8262
#   Recall:    0.5473
#   F1-score:  0.6584
#   Support:   634
# loneliness:
#   Precision: 0.8243
#   Recall:    0.5810
#   F1-score:  0.6816
#   Support:   420
# sadness:
#   Precision: 0.8758
#   Recall:    0.5968
#   F1-score:  0.7099
#   Support:   697
# suicide intent:
#   Precision: 0.6842
#   Recall:    0.3362
#   F1-score:  0.4509
#   Support:   232
# worthlessness:
#   Precision: 0.6667
#   Recall:    0.4977
# ...

# %% [markdown]
# ### Qwen3.5-2B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test_binary.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-2B-Base/lora/eval_2026-03-17-05-15-18_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：如果包含 '0' 返回0，否则如果包含 '1' 返回1，否则默认返回1"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    else:
        return 1  # 默认返回1

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        # target 可能为字符串 '0' 或 '1'，转为整数
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算指标
accuracy = accuracy_score(true_labels, pred_labels)
precision = precision_score(true_labels, pred_labels, pos_label=1) # pos_label=1 指定正类为抑郁（1）
recall = recall_score(true_labels, pred_labels, pos_label=1)
f1 = f1_score(true_labels, pred_labels, pos_label=1)

# 5. 打印结果
print("评估结果：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}")
print(f"精确率 (Precision): {precision*100:.2f}")
print(f"召回率 (Recall): {recall*100:.2f}")
print(f"F1 值 (F1-score): {f1*100:.2f}")
# Out:
# 评估结果：
# 准确率 (Accuracy): 87.78
# 精确率 (Precision): 71.43
# 召回率 (Recall): 62.04
# F1 值 (F1-score): 66.41

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-2B-Base/lora/eval_2026-03-17-05-15-18_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.1026
# Hamming Loss: 0.2886
#
# Macro Precision: 0.6217
# Macro Recall:    0.6065
# Macro F1-score:  0.6071
#
# Micro Precision: 0.6804
# Micro Recall:    0.6808
# Micro F1-score:  0.6806
#
# 每个类别的指标：
# anger:
#   Precision: 0.4901
#   Recall:    0.5768
#   F1-score:  0.5300
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.3134
#   Recall:    0.1228
#   F1-score:  0.1765
#   Support:   171
# emptiness:
#   Precision: 0.5630
#   Recall:    0.6158
#   F1-score:  0.5882
#   Support:   341
# hopelessness:
#   Precision: 0.7618
#   Recall:    0.8423
#   F1-score:  0.8000
#   Support:   634
# loneliness:
#   Precision: 0.6612
#   Recall:    0.6690
#   F1-score:  0.6651
#   Support:   420
# sadness:
#   Precision: 0.8224
#   Recall:    0.8436
#   F1-score:  0.8329
#   Support:   697
# suicide intent:
#   Precision: 0.7053
#   Recall:    0.5776
#   F1-score:  0.6351
#   Support:   232
# worthlessness:
#   Precision: 0.6566
#   Recall:    0.6037
# ...

# %% [markdown]
# ### Qwen3.5-4B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test_binary.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-4B-Base/lora/eval_2026-03-17-05-15-18_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：如果包含 '0' 返回0，否则如果包含 '1' 返回1，否则默认返回1"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    else:
        return 1  # 默认返回1

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        # target 可能为字符串 '0' 或 '1'，转为整数
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算指标
accuracy = accuracy_score(true_labels, pred_labels)
precision = precision_score(true_labels, pred_labels, pos_label=1) # pos_label=1 指定正类为抑郁（1）
recall = recall_score(true_labels, pred_labels, pos_label=1)
f1 = f1_score(true_labels, pred_labels, pos_label=1)

# 5. 打印结果
print("评估结果：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}")
print(f"精确率 (Precision): {precision*100:.2f}")
print(f"召回率 (Recall): {recall*100:.2f}")
print(f"F1 值 (F1-score): {f1*100:.2f}")
# Out:
# 评估结果：
# 准确率 (Accuracy): 87.71
# 精确率 (Precision): 71.86
# 召回率 (Recall): 60.58
# F1 值 (F1-score): 65.74

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-4B-Base/lora/eval_2026-03-17-05-15-18_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.1026
# Hamming Loss: 0.2649
#
# Macro Precision: 0.7520
# Macro Recall:    0.5425
# Macro F1-score:  0.6108
#
# Micro Precision: 0.7687
# Micro Recall:    0.5916
# Micro F1-score:  0.6686
#
# 每个类别的指标：
# anger:
#   Precision: 0.5318
#   Recall:    0.6783
#   F1-score:  0.5962
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.5714
#   Recall:    0.1404
#   F1-score:  0.2254
#   Support:   171
# emptiness:
#   Precision: 0.6926
#   Recall:    0.5748
#   F1-score:  0.6282
#   Support:   341
# hopelessness:
#   Precision: 0.8346
#   Recall:    0.6688
#   F1-score:  0.7426
#   Support:   634
# loneliness:
#   Precision: 0.8815
#   Recall:    0.6024
#   F1-score:  0.7157
#   Support:   420
# sadness:
#   Precision: 0.8515
#   Recall:    0.7403
#   F1-score:  0.7920
#   Support:   697
# suicide intent:
#   Precision: 0.8750
#   Recall:    0.5733
#   F1-score:  0.6927
#   Support:   232
# worthlessness:
#   Precision: 0.7772
#   Recall:    0.3618
# ...

# %% [markdown]
# ### Qwen3.5-9B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test_binary.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-9B-Base/lora/eval_2026-03-17-05-15-18_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：如果包含 '0' 返回0，否则如果包含 '1' 返回1，否则默认返回1"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    else:
        return 1  # 默认返回1

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        # target 可能为字符串 '0' 或 '1'，转为整数
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算指标
accuracy = accuracy_score(true_labels, pred_labels)
precision = precision_score(true_labels, pred_labels, pos_label=1) # pos_label=1 指定正类为抑郁（1）
recall = recall_score(true_labels, pred_labels, pos_label=1)
f1 = f1_score(true_labels, pred_labels, pos_label=1)

# 5. 打印结果
print("评估结果：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}")
print(f"精确率 (Precision): {precision*100:.2f}")
print(f"召回率 (Recall): {recall*100:.2f}")
print(f"F1 值 (F1-score): {f1*100:.2f}")
# Out:
# 评估结果：
# 准确率 (Accuracy): 88.14
# 精确率 (Precision): 72.57
# 召回率 (Recall): 62.77
# F1 值 (F1-score): 67.32

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-9B-Base/lora/eval_2026-03-17-05-15-18_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.1501
# Hamming Loss: 0.2497
#
# Macro Precision: 0.6895
# Macro Recall:    0.6573
# Macro F1-score:  0.6659
#
# Micro Precision: 0.7272
# Micro Recall:    0.7156
# Micro F1-score:  0.7214
#
# 每个类别的指标：
# anger:
#   Precision: 0.5816
#   Recall:    0.7130
#   F1-score:  0.6406
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.4227
#   Recall:    0.2398
#   F1-score:  0.3060
#   Support:   171
# emptiness:
#   Precision: 0.6220
#   Recall:    0.6950
#   F1-score:  0.6565
#   Support:   341
# hopelessness:
#   Precision: 0.8003
#   Recall:    0.8344
#   F1-score:  0.8170
#   Support:   634
# loneliness:
#   Precision: 0.7196
#   Recall:    0.7762
#   F1-score:  0.7468
#   Support:   420
# sadness:
#   Precision: 0.8418
#   Recall:    0.8321
#   F1-score:  0.8369
#   Support:   697
# suicide intent:
#   Precision: 0.8294
#   Recall:    0.6078
#   F1-score:  0.7015
#   Support:   232
# worthlessness:
#   Precision: 0.6983
#   Recall:    0.5599
# ...

# %% [markdown]
# ### Qwen3.5-35B-A3B-Base

# %%
import json
import csv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 文件路径
test_csv_path = "/data/zhengtianlong/Private/Depressed/Deptweet/Deptweet_test_binary.csv"
pred_jsonl_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-35B-A3B-Base/lora/eval_2026-03-17-05-15-18_1/generated_predictions.jsonl"

def map_label(predict_str):
    """根据预测字符串提取标签：如果包含 '0' 返回0，否则如果包含 '1' 返回1，否则默认返回1"""
    if "0" in predict_str:
        return 0
    elif "1" in predict_str:
        return 1
    else:
        return 1  # 默认返回1

# 1. 读取测试集标签
true_labels = []
with open(test_csv_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)  # 跳过表头
    for row in reader:
        if len(row) < 3:
            continue
        target = row[2]  # 第三列是 target
        # target 可能为字符串 '0' 或 '1'，转为整数
        true_labels.append(int(target))

# 2. 读取预测结果
pred_labels = []
with open(pred_jsonl_path, 'r', encoding='utf-8') as f:
    for line in f:
        data = json.loads(line.strip())
        predict = data.get("predict", "")
        pred_labels.append(map_label(predict))

# 3. 检查数量一致性
if len(true_labels) != len(pred_labels):
    print(f"警告：真实标签数量 {len(true_labels)}，预测标签数量 {len(pred_labels)}，将按较小数量计算。")
    min_len = min(len(true_labels), len(pred_labels))
    true_labels = true_labels[:min_len]
    pred_labels = pred_labels[:min_len]

# 4. 计算指标
accuracy = accuracy_score(true_labels, pred_labels)
precision = precision_score(true_labels, pred_labels, pos_label=1)
recall = recall_score(true_labels, pred_labels, pos_label=1)
f1 = f1_score(true_labels, pred_labels, pos_label=1)

# 5. 打印结果
print("评估结果：")
print(f"准确率 (Accuracy): {accuracy*100:.2f}")
print(f"精确率 (Precision): {precision*100:.2f}")
print(f"召回率 (Recall): {recall*100:.2f}")
print(f"F1 值 (F1-score): {f1*100:.2f}")
# Out:
# 评估结果：
# 准确率 (Accuracy): 89.13
# 精确率 (Precision): 75.97
# 召回率 (Recall): 64.60
# F1 值 (F1-score): 69.82

# %%
import json
import re
import numpy as np
from sklearn.metrics import (
    accuracy_score, hamming_loss, f1_score,
    precision_score, recall_score,
    precision_recall_fscore_support
)

# ========== 配置 ==========
input_json_path = "/data/zhengtianlong/Private/Depressed/LlamaFactory/saves/Qwen3.5-35B-A3B-Base/lora/eval_2026-03-17-05-15-18_2/generated_predictions.jsonl"

# 情绪代码到英文名称的映射（顺序固定，用于二进制向量）
emotion_codes = ['甲', '乙', '丙', '丁', '戊', '己', '庚', '辛']
emotion_names = [
    'anger',
    'brain dysfunction (forget)',
    'emptiness',
    'hopelessness',
    'loneliness',
    'sadness',
    'suicide intent',
    'worthlessness'
]
code_to_name = dict(zip(emotion_codes, emotion_names))

# ========== 工具函数 ==========
def extract_codes(text, emotion_codes):
    """
    从字符串中提取情绪代码，返回集合。
    例如：
    '<think>...</think>\\n\\n丁, 己' -> {'丁', '己'}
    """
    if text is None:
        return set()
    text = str(text)

    # 去掉 <think>...</think>，避免干扰
    text = re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

    # 只保留出现过的合法代码
    codes = {code for code in emotion_codes if code in text}
    return codes


def codes_to_multihot(code_set, emotion_codes):
    """
    将代码集合转为多标签二进制向量
    """
    return [1 if code in code_set else 0 for code in emotion_codes]


# ========== 读取数据 ==========
data = []
with open(input_json_path, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        data.append(json.loads(line))

# ========== 解析预测和真实标签 ==========
y_true = []   # 真实二进制向量
y_pred = []   # 预测二进制向量

for item in data:
    # 真实标签：来自 label 字段
    label_str = item.get("label", "")
    true_codes = extract_codes(label_str, emotion_codes)
    true_vec = codes_to_multihot(true_codes, emotion_codes)
    y_true.append(true_vec)

    # 预测标签：来自 predict 字段
    pred_str = item.get("predict", "")
    pred_codes = extract_codes(pred_str, emotion_codes)
    pred_vec = codes_to_multihot(pred_codes, emotion_codes)
    y_pred.append(pred_vec)

# 转换为 numpy 数组
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# ========== 计算指标 ==========
# 1. Exact Match Ratio (准确率)
exact_match = accuracy_score(y_true, y_pred)
print(f"Exact Match Ratio (准确率): {exact_match:.4f}")

# 2. Hamming Loss
h_loss = hamming_loss(y_true, y_pred)
print(f"Hamming Loss: {h_loss:.4f}")

# 3. 宏平均指标
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall:    {recall_macro:.4f}")
print(f"Macro F1-score:  {f1_macro:.4f}")

# 4. 微平均指标
precision_micro = precision_score(y_true, y_pred, average='micro', zero_division=0)
recall_micro = recall_score(y_true, y_pred, average='micro', zero_division=0)
f1_micro = f1_score(y_true, y_pred, average='micro', zero_division=0)
print(f"\nMicro Precision: {precision_micro:.4f}")
print(f"Micro Recall:    {recall_micro:.4f}")
print(f"Micro F1-score:  {f1_micro:.4f}")

# 5. 每个类别的精确率、召回率、F1-score
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, zero_division=0
)

print("\n每个类别的指标：")
for i, name in enumerate(emotion_names):
    print(f"{name}:")
    print(f"  Precision: {precision[i]:.4f}")
    print(f"  Recall:    {recall[i]:.4f}")
    print(f"  F1-score:  {f1[i]:.4f}")
    print(f"  Support:   {support[i]}")

# 可选：输出总体统计
print(f"\n总样本数: {len(data)}")
# Out:
# Exact Match Ratio (准确率): 0.1302
# Hamming Loss: 0.2504
#
# Macro Precision: 0.7227
# Macro Recall:    0.5749
# Macro F1-score:  0.6331
#
# Micro Precision: 0.7661
# Micro Recall:    0.6414
# Micro F1-score:  0.6983
#
# 每个类别的指标：
# anger:
#   Precision: 0.6401
#   Recall:    0.6290
#   F1-score:  0.6345
#   Support:   345
# brain dysfunction (forget):
#   Precision: 0.3058
#   Recall:    0.2164
#   F1-score:  0.2534
#   Support:   171
# emptiness:
#   Precision: 0.7634
#   Recall:    0.4164
#   F1-score:  0.5389
#   Support:   341
# hopelessness:
#   Precision: 0.8333
#   Recall:    0.7492
#   F1-score:  0.7890
#   Support:   634
# loneliness:
#   Precision: 0.8280
#   Recall:    0.6190
#   F1-score:  0.7084
#   Support:   420
# sadness:
#   Precision: 0.8189
#   Recall:    0.8824
#   F1-score:  0.8494
#   Support:   697
# suicide intent:
#   Precision: 0.8766
#   Recall:    0.5819
#   F1-score:  0.6995
#   Support:   232
# worthlessness:
#   Precision: 0.7157
#   Recall:    0.5046
# ...
