# %% [markdown]
# ### Llama-3.1-8B-Instruct

# %%
import json, random
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 读取JSON文件
input_file_path = '/data/zhentianlong/paper6/Close_LLM_Deptweet/Llama-3.1-8B-Instruct_Depression.json'
data = []

with open(input_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 提取预测值和真实标签
def map_label(predict):
    if "甲" in predict:
        return 0
    elif "乙" in predict:
        return 1
    elif "丙" in predict:
        return 2
    elif "丁" in predict:
        return 3
    else:
        return 3 
        # 为什么要返回3而不是其他 答：模型选择不回答，有可能是因为抑郁症过于严重导致语言过于激烈导致模型无法回答
        # return random.choice([0, 1, 2, 3])

y_true = [int(item["label"]) for item in data]
y_pred = [map_label(item["predict"]) for item in data]

# 计算指标
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='macro')
recall = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')

print(f'Accuracy: {accuracy * 100:.2f}%')
print(f'Precision: {precision * 100:.2f}%')
print(f'Recall: {recall * 100:.2f}%')
print(f'F1 Score: {f1 * 100:.2f}%')
# Out:
# Accuracy: 32.03%
# Precision: 33.87%
# Recall: 51.26%
# F1 Score: 24.99%

# %%
import json
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 加载 Times New Roman 字体
font_path = '/data/zhentianlong/code1/timesi.ttf'
times_new_roman_font = fm.FontProperties(fname=font_path)

# 读取JSON文件
input_file_path = '/data/zhentianlong/paper6/Close_LLM_Deptweet/Llama-3.1-8B-Instruct_Depression.json'

with open(input_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 提取预测值和真实标签
def map_label(predict):
    if "甲" in predict:
        return 0
    elif "乙" in predict:
        return 1
    elif "丙" in predict:
        return 2
    elif "丁" in predict:
        return 3
    else:
        return 3

y_true = [int(item["label"]) for item in data]
y_pred = [map_label(item["predict"]) for item in data]

# 将标签二值化
n_classes = 4
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])
# 类名映射
class_names = {0: "non-depressed", 1: "mild", 2: "moderate", 3: "severe"}
# 计算ROC曲线和AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_pred_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类别的ROC曲线
plt.figure()
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             lw=2, label=f'{class_names[i]} (area = {roc_auc[i]:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontproperties=times_new_roman_font)
plt.ylabel('True Positive Rate', fontproperties=times_new_roman_font)
plt.title('Receiver Operating Characteristic (ROC) for each level', fontproperties=times_new_roman_font)
plt.legend(loc="lower right", prop=times_new_roman_font)

# 设置刻度字体
plt.xticks(fontproperties=times_new_roman_font)
plt.yticks(fontproperties=times_new_roman_font)

plt.savefig('/data/zhentianlong/paper6/result_IMG/Llama-3.1-8B-Instruct_curves.png', format='png', dpi=800, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### hunyuan-lite

# %%
import json, random
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 读取JSON文件
input_file_path = '/data/zhentianlong/paper6/Close_LLM_Deptweet/hunyuan-lite_Depression.json'
data = []

with open(input_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 提取预测值和真实标签
def map_label(predict):
    if "甲" in predict:
        return 0
    elif "乙" in predict:
        return 1
    elif "丙" in predict:
        return 2
    elif "丁" in predict:
        return 3
    else:
        return 3

y_true = [int(item["label"]) for item in data]
y_pred = [map_label(item["predict"]) for item in data]

# 计算指标
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='macro')
recall = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')

print(f'Accuracy: {accuracy * 100:.2f}%')
print(f'Precision: {precision * 100:.2f}%')
print(f'Recall: {recall * 100:.2f}%')
print(f'F1 Score: {f1 * 100:.2f}%')
# Out:
# Accuracy: 63.40%
# Precision: 33.73%
# Recall: 47.13%
# F1 Score: 32.67%

# %%
import json
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 加载 Times New Roman 字体
font_path = '/data/zhentianlong/code1/timesi.ttf'
times_new_roman_font = fm.FontProperties(fname=font_path)

# 读取JSON文件
input_file_path = '/data/zhentianlong/paper6/Close_LLM_Deptweet/hunyuan-lite_Depression.json'

with open(input_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 提取预测值和真实标签
def map_label(predict):
    if "甲" in predict:
        return 0
    elif "乙" in predict:
        return 1
    elif "丙" in predict:
        return 2
    elif "丁" in predict:
        return 3
    else:
        return 3

y_true = [int(item["label"]) for item in data]
y_pred = [map_label(item["predict"]) for item in data]

# 将标签二值化
n_classes = 4
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])
# 类名映射
class_names = {0: "non-depressed", 1: "mild", 2: "moderate", 3: "severe"}
# 计算ROC曲线和AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_pred_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类别的ROC曲线
plt.figure()
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             lw=2, label=f'{class_names[i]} (area = {roc_auc[i]:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontproperties=times_new_roman_font)
plt.ylabel('True Positive Rate', fontproperties=times_new_roman_font)
plt.title('Receiver Operating Characteristic (ROC) for each level', fontproperties=times_new_roman_font)
plt.legend(loc="lower right", prop=times_new_roman_font)

# 设置刻度字体
plt.xticks(fontproperties=times_new_roman_font)
plt.yticks(fontproperties=times_new_roman_font)

plt.savefig('/data/zhentianlong/paper6/result_IMG/hunyuan-lite_curves.png', format='png', dpi=800, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### glm-4-flash

# %%
import json, random
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 读取JSON文件
input_file_path = '/data/zhentianlong/paper6/Close_LLM_Deptweet/glm-4-flash_Depression.json'
data = []

with open(input_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 提取预测值和真实标签
def map_label(predict):
    if "甲" in predict:
        return 0
    elif "乙" in predict:
        return 1
    elif "丙" in predict:
        return 2
    elif "丁" in predict:
        return 3
    else:
        return 3

y_true = [int(item["label"]) for item in data]
y_pred = [map_label(item["predict"]) for item in data]

# 计算指标
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='macro')
recall = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')

print(f'Accuracy: {accuracy * 100:.2f}%')
print(f'Precision: {precision * 100:.2f}%')
print(f'Recall: {recall * 100:.2f}%')
print(f'F1 Score: {f1 * 100:.2f}%')
# Out:
# Accuracy: 34.30%
# Precision: 38.87%
# Recall: 54.21%
# F1 Score: 29.40%

# %%
import json
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 加载 Times New Roman 字体
font_path = '/data/zhentianlong/code1/timesi.ttf'
times_new_roman_font = fm.FontProperties(fname=font_path)

# 读取JSON文件
input_file_path = '/data/zhentianlong/paper6/Close_LLM_Deptweet/glm-4-flash_Depression.json'

with open(input_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 提取预测值和真实标签
def map_label(predict):
    if "甲" in predict:
        return 0
    elif "乙" in predict:
        return 1
    elif "丙" in predict:
        return 2
    elif "丁" in predict:
        return 3
    else:
        return 3

y_true = [int(item["label"]) for item in data]
y_pred = [map_label(item["predict"]) for item in data]

# 将标签二值化
n_classes = 4
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])
# 类名映射
class_names = {0: "non-depressed", 1: "mild", 2: "moderate", 3: "severe"}
# 计算ROC曲线和AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_pred_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类别的ROC曲线
plt.figure()
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             lw=2, label=f'{class_names[i]} (area = {roc_auc[i]:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontproperties=times_new_roman_font)
plt.ylabel('True Positive Rate', fontproperties=times_new_roman_font)
plt.title('Receiver Operating Characteristic (ROC) for each level', fontproperties=times_new_roman_font)
plt.legend(loc="lower right", prop=times_new_roman_font)

# 设置刻度字体
plt.xticks(fontproperties=times_new_roman_font)
plt.yticks(fontproperties=times_new_roman_font)

plt.savefig('/data/zhentianlong/paper6/result_IMG/glm-4-flash_curves.png', format='png', dpi=800, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### THUDM/glm-4-9b-chat

# %%
import json, random
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 读取JSON文件
input_file_path = '/data/zhentianlong/paper6/Close_LLM_Deptweet/THUDM_glm-4-9b-chat_Depression.json'
data = []

with open(input_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 提取预测值和真实标签
def map_label(predict):
    if "甲" in predict:
        return 0
    elif "乙" in predict:
        return 1
    elif "丙" in predict:
        return 2
    elif "丁" in predict:
        return 3
    else:
        return 3

y_true = [int(item["label"]) for item in data]
y_pred = [map_label(item["predict"]) for item in data]

# 计算指标
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='macro')
recall = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')

print(f'Accuracy: {accuracy * 100:.2f}%')
print(f'Precision: {precision * 100:.2f}%')
print(f'Recall: {recall * 100:.2f}%')
print(f'F1 Score: {f1 * 100:.2f}%')
# Out:
# Accuracy: 34.26%
# Precision: 37.97%
# Recall: 54.66%
# F1 Score: 29.47%

# %%
import json
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 加载 Times New Roman 字体
font_path = '/data/zhentianlong/code1/timesi.ttf'
times_new_roman_font = fm.FontProperties(fname=font_path)

# 读取JSON文件
input_file_path = '/data/zhentianlong/paper6/Close_LLM_Deptweet/THUDM_glm-4-9b-chat_Depression.json'

with open(input_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 提取预测值和真实标签
def map_label(predict):
    if "甲" in predict:
        return 0
    elif "乙" in predict:
        return 1
    elif "丙" in predict:
        return 2
    elif "丁" in predict:
        return 3
    else:
        return 3

y_true = [int(item["label"]) for item in data]
y_pred = [map_label(item["predict"]) for item in data]

# 将标签二值化
n_classes = 4
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])
# 类名映射
class_names = {0: "non-depressed", 1: "mild", 2: "moderate", 3: "severe"}
# 计算ROC曲线和AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_pred_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类别的ROC曲线
plt.figure()
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             lw=2, label=f'{class_names[i]} (area = {roc_auc[i]:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontproperties=times_new_roman_font)
plt.ylabel('True Positive Rate', fontproperties=times_new_roman_font)
plt.title('Receiver Operating Characteristic (ROC) for each level', fontproperties=times_new_roman_font)
plt.legend(loc="lower right", prop=times_new_roman_font)

# 设置刻度字体
plt.xticks(fontproperties=times_new_roman_font)
plt.yticks(fontproperties=times_new_roman_font)

plt.savefig('/data/zhentianlong/paper6/result_IMG/THUDM_glm-4-9b-chat_curves.png', format='png', dpi=800, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### ERNIE-Speed-128K

# %%
import json, random
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 读取JSON文件
input_file_path = '/data/zhentianlong/paper6/Close_LLM_Deptweet/ERNIE-Speed-128K_Depression.json'
data = []

with open(input_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 提取预测值和真实标签
def map_label(predict):
    if "甲" in predict:
        return 0
    elif "乙" in predict:
        return 1
    elif "丙" in predict:
        return 2
    elif "丁" in predict:
        return 3
    else:
        return 3

y_true = [int(item["label"]) for item in data]
y_pred = [map_label(item["predict"]) for item in data]

# 计算指标
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='macro')
recall = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')

print(f'Accuracy: {accuracy * 100:.2f}%')
print(f'Precision: {precision * 100:.2f}%')
print(f'Recall: {recall * 100:.2f}%')
print(f'F1 Score: {f1 * 100:.2f}%')
# Out:
# Accuracy: 67.97%
# Precision: 39.44%
# Recall: 55.24%
# F1 Score: 39.25%

# %%
import json
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 加载 Times New Roman 字体
font_path = '/data/zhentianlong/code1/timesi.ttf'
times_new_roman_font = fm.FontProperties(fname=font_path)

# 读取JSON文件
input_file_path = '/data/zhentianlong/paper6/Close_LLM_Deptweet/ERNIE-Speed-128K_Depression.json'

with open(input_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 提取预测值和真实标签
def map_label(predict):
    if "甲" in predict:
        return 0
    elif "乙" in predict:
        return 1
    elif "丙" in predict:
        return 2
    elif "丁" in predict:
        return 3
    else:
        return 3

y_true = [int(item["label"]) for item in data]
y_pred = [map_label(item["predict"]) for item in data]

# 将标签二值化
n_classes = 4
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])
# 类名映射
class_names = {0: "non-depressed", 1: "mild", 2: "moderate", 3: "severe"}
# 计算ROC曲线和AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_pred_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类别的ROC曲线
plt.figure()
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             lw=2, label=f'{class_names[i]} (area = {roc_auc[i]:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontproperties=times_new_roman_font)
plt.ylabel('True Positive Rate', fontproperties=times_new_roman_font)
plt.title('Receiver Operating Characteristic (ROC) for each level', fontproperties=times_new_roman_font)
plt.legend(loc="lower right", prop=times_new_roman_font)

# 设置刻度字体
plt.xticks(fontproperties=times_new_roman_font)
plt.yticks(fontproperties=times_new_roman_font)

plt.savefig('/data/zhentianlong/paper6/result_IMG/ERNIE-Speed-128K_curves.png', format='png', dpi=800, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 01-ai/Yi-1.5-9B-Chat-16K

# %%
import json, random
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 读取JSON文件
input_file_path = '/data/zhentianlong/paper6/Close_LLM_Deptweet/Yi-1.5-9B-Chat-16K_Depression.json'
data = []

with open(input_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 提取预测值和真实标签
def map_label(predict):
    if "甲" in predict:
        return 0
    elif "乙" in predict:
        return 1
    elif "丙" in predict:
        return 2
    elif "丁" in predict:
        return 3
    else:
        return 3

y_true = [int(item["label"]) for item in data]
y_pred = [map_label(item["predict"]) for item in data]

# 计算指标
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='macro')
recall = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')

print(f'Accuracy: {accuracy * 100:.2f}%')
print(f'Precision: {precision * 100:.2f}%')
print(f'Recall: {recall * 100:.2f}%')
print(f'F1 Score: {f1 * 100:.2f}%')
# Out:
# Accuracy: 62.43%
# Precision: 42.21%
# Recall: 61.21%
# F1 Score: 41.87%

# %%
import json
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 加载 Times New Roman 字体
font_path = '/data/zhentianlong/code1/timesi.ttf'
times_new_roman_font = fm.FontProperties(fname=font_path)

# 读取JSON文件
input_file_path = '/data/zhentianlong/paper6/Close_LLM_Deptweet/Yi-1.5-9B-Chat-16K_Depression.json'

with open(input_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 提取预测值和真实标签
def map_label(predict):
    if "甲" in predict:
        return 0
    elif "乙" in predict:
        return 1
    elif "丙" in predict:
        return 2
    elif "丁" in predict:
        return 3
    else:
        return 3

y_true = [int(item["label"]) for item in data]
y_pred = [map_label(item["predict"]) for item in data]

# 将标签二值化
n_classes = 4
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])
# 类名映射
class_names = {0: "non-depressed", 1: "mild", 2: "moderate", 3: "severe"}
# 计算ROC曲线和AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_pred_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类别的ROC曲线
plt.figure()
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             lw=2, label=f'{class_names[i]} (area = {roc_auc[i]:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontproperties=times_new_roman_font)
plt.ylabel('True Positive Rate', fontproperties=times_new_roman_font)
plt.title('Receiver Operating Characteristic (ROC) for each level', fontproperties=times_new_roman_font)
plt.legend(loc="lower right", prop=times_new_roman_font)

# 设置刻度字体
plt.xticks(fontproperties=times_new_roman_font)
plt.yticks(fontproperties=times_new_roman_font)

plt.savefig('/data/zhentianlong/paper6/result_IMG/Yi-1.5-9B-Chat-16K_curves.png', format='png', dpi=800, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Qwen/Qwen2.5-7B-Instruct

# %%
import json, random
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 读取JSON文件
input_file_path = '/data/zhentianlong/paper6/Close_LLM_Deptweet/Qwen2.5-7B-Instruct_Depression.json'
data = []

with open(input_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 提取预测值和真实标签
def map_label(predict):
    if "甲" in predict:
        return 0
    elif "乙" in predict:
        return 1
    elif "丙" in predict:
        return 2
    elif "丁" in predict:
        return 3
    else:
        return 3

y_true = [int(item["label"]) for item in data]
y_pred = [map_label(item["predict"]) for item in data]

# 计算指标
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='macro')
recall = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')

print(f'Accuracy: {accuracy * 100:.2f}%')
print(f'Precision: {precision * 100:.2f}%')
print(f'Recall: {recall * 100:.2f}%')
print(f'F1 Score: {f1 * 100:.2f}%')
# Out:
# Accuracy: 66.76%
# Precision: 44.29%
# Recall: 60.62%
# F1 Score: 44.15%

# %%
import json
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 加载 Times New Roman 字体
font_path = '/data/zhentianlong/code1/timesi.ttf'
times_new_roman_font = fm.FontProperties(fname=font_path)

# 读取JSON文件
input_file_path = '/data/zhentianlong/paper6/Close_LLM_Deptweet/Qwen2.5-7B-Instruct_Depression.json'

with open(input_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 提取预测值和真实标签
def map_label(predict):
    if "甲" in predict:
        return 0
    elif "乙" in predict:
        return 1
    elif "丙" in predict:
        return 2
    elif "丁" in predict:
        return 3
    else:
        return 3

y_true = [int(item["label"]) for item in data]
y_pred = [map_label(item["predict"]) for item in data]

# 将标签二值化
n_classes = 4
y_true_binarized = label_binarize(y_true, classes=[0, 1, 2, 3])
y_pred_binarized = label_binarize(y_pred, classes=[0, 1, 2, 3])
# 类名映射
class_names = {0: "non-depressed", 1: "mild", 2: "moderate", 3: "severe"}
# 计算ROC曲线和AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_binarized[:, i], y_pred_binarized[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类别的ROC曲线
plt.figure()
colors = ['aqua', 'darkorange', 'cornflowerblue', 'green']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             lw=2, label=f'{class_names[i]} (area = {roc_auc[i]:.4f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontproperties=times_new_roman_font)
plt.ylabel('True Positive Rate', fontproperties=times_new_roman_font)
plt.title('Receiver Operating Characteristic (ROC) for each level', fontproperties=times_new_roman_font)
plt.legend(loc="lower right", prop=times_new_roman_font)

# 设置刻度字体
plt.xticks(fontproperties=times_new_roman_font)
plt.yticks(fontproperties=times_new_roman_font)

plt.savefig('/data/zhentianlong/paper6/result_IMG/Qwen2.5-7B-Instruct_curves.png', format='png', dpi=800, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Llama-3.1-8B-Instruct

# %%
import json, random
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 读取JSON文件
input_file_path = '/data/zhentianlong/paper6/Close_LLM_Deptweet/Bin_Llama-3.1-8B-Instruct_Depression.json'
data = []

with open(input_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 提取预测值和真实标签
def map_label(predict):
    if "甲" in predict:
        return 0
    elif "乙" in predict:
        return 1
    else:
        return 1

y_true = [int(item["label"]) for item in data]
y_pred = [map_label(item["predict"]) for item in data]
# print(set(y_pred))
# print(set(y_true))

# 计算指标
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)

print(f'Accuracy: {accuracy * 100:.2f}%')
print(f'Precision: {precision * 100:.2f}%')
print(f'Recall: {recall * 100:.2f}%')
print(f'F1 Score: {f1 * 100:.2f}%')
# Out:
# Accuracy: 64.39%
# Precision: 33.77%
# Recall: 87.04%
# F1 Score: 48.66%

# %% [markdown]
# ### hunyuan-lite

# %%
import json, random
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 读取JSON文件
input_file_path = '/data/zhentianlong/paper6/Close_LLM_Deptweet/Bin_hunyuan-lite_Depression.json'
data = []

with open(input_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 提取预测值和真实标签
def map_label(predict):
    if "甲" in predict:
        return 0
    elif "乙" in predict:
        return 1
    else:
        return 1

y_true = [int(item["label"]) for item in data]
y_pred = [map_label(item["predict"]) for item in data]

# 计算指标
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)

print(f'Accuracy: {accuracy * 100:.2f}%')
print(f'Precision: {precision * 100:.2f}%')
print(f'Recall: {recall * 100:.2f}%')
print(f'F1 Score: {f1 * 100:.2f}%')
# Out:
# Accuracy: 50.98%
# Precision: 27.79%
# Recall: 95.57%
# F1 Score: 43.06%

# %% [markdown]
# ### glm-4-flash

# %%
import json, random
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 读取JSON文件
input_file_path = '/data/zhentianlong/paper6/Close_LLM_Deptweet/Bin_glm-4-flash_Depression.json'
data = []

with open(input_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 提取预测值和真实标签
def map_label(predict):
    if "甲" in predict:
        return 0
    elif "乙" in predict:
        return 1
    else:
        return 1

y_true = [int(item["label"]) for item in data]
y_pred = [map_label(item["predict"]) for item in data]

# 计算指标
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)

print(f'Accuracy: {accuracy * 100:.2f}%')
print(f'Precision: {precision * 100:.2f}%')
print(f'Recall: {recall * 100:.2f}%')
print(f'F1 Score: {f1 * 100:.2f}%')
# Out:
# Accuracy: 66.75%
# Precision: 36.06%
# Recall: 92.43%
# F1 Score: 51.88%

# %% [markdown]
# ### THUDM/glm-4-9b-chat

# %%
import json, random
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 读取JSON文件
input_file_path = '/data/zhentianlong/paper6/Close_LLM_Deptweet/Bin_THUDM_glm-4-9b-chat_Depression.json'
data = []

with open(input_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 提取预测值和真实标签
def map_label(predict):
    if "甲" in predict:
        return 0
    elif "乙" in predict:
        return 1
    else:
        return 1

y_true = [int(item["label"]) for item in data]
y_pred = [map_label(item["predict"]) for item in data]

# 计算指标
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)

print(f'Accuracy: {accuracy * 100:.2f}%')
print(f'Precision: {precision * 100:.2f}%')
print(f'Recall: {recall * 100:.2f}%')
print(f'F1 Score: {f1 * 100:.2f}%')
# Out:
# Accuracy: 66.69%
# Precision: 35.98%
# Recall: 92.11%
# F1 Score: 51.75%

# %% [markdown]
# ### ERNIE-Speed-128K

# %%
import json, random
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 读取JSON文件
input_file_path = '/data/zhentianlong/paper6/Close_LLM_Deptweet/Bin_ERNIE-Speed-128K_Depression.json'
data = []

with open(input_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 提取预测值和真实标签
def map_label(predict):
    if "甲" in predict:
        return 0
    elif "乙" in predict:
        return 1
    else:
        return 1

y_true = [int(item["label"]) for item in data]
y_pred = [map_label(item["predict"]) for item in data]

# 计算指标
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)

print(f'Accuracy: {accuracy * 100:.2f}%')
print(f'Precision: {precision * 100:.2f}%')
print(f'Recall: {recall * 100:.2f}%')
print(f'F1 Score: {f1 * 100:.2f}%')
# Out:
# Accuracy: 77.70%
# Precision: 45.49%
# Recall: 75.63%
# F1 Score: 56.81%

# %% [markdown]
# ### 01-ai/Yi-1.5-9B-Chat-16K

# %%
import json, random
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 读取JSON文件
input_file_path = '/data/zhentianlong/paper6/Close_LLM_Deptweet/Bin_Yi-1.5-9B-Chat-16K_Depression.json'
data = []

with open(input_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 提取预测值和真实标签
def map_label(predict):
    if "甲" in predict:
        return 0
    elif "乙" in predict:
        return 1
    else:
        return 1

y_true = [int(item["label"]) for item in data]
y_pred = [map_label(item["predict"]) for item in data]

# 计算指标
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)

print(f'Accuracy: {accuracy * 100:.2f}%')
print(f'Precision: {precision * 100:.2f}%')
print(f'Recall: {recall * 100:.2f}%')
print(f'F1 Score: {f1 * 100:.2f}%')
# Out:
# Accuracy: 72.96%
# Precision: 41.05%
# Recall: 90.44%
# F1 Score: 56.47%

# %% [markdown]
# ### Qwen/Qwen2.5-7B-Instruct

# %%
import json, random
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 读取JSON文件
input_file_path = '/data/zhentianlong/paper6/Close_LLM_Deptweet/Bin_Qwen2.5-7B-Instruct_Depression.json'
data = []

with open(input_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 提取预测值和真实标签
def map_label(predict):
    if "甲" in predict:
        return 0
    elif "乙" in predict:
        return 1
    else:
        return 1

y_true = [int(item["label"]) for item in data]
y_pred = [map_label(item["predict"]) for item in data]

# 计算指标
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)

print(f'Accuracy: {accuracy * 100:.2f}%')
print(f'Precision: {precision * 100:.2f}%')
print(f'Recall: {recall * 100:.2f}%')
print(f'F1 Score: {f1 * 100:.2f}%')
# Out:
# Accuracy: 79.99%
# Precision: 48.98%
# Recall: 76.97%
# F1 Score: 59.87%
